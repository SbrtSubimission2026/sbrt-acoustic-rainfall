# %% [markdown]
# # Imports and Configurations

# %%
# Experiment
EXP_NUM = 3
DATASET = 'UECE'
CONTENT = 'dry/wet'
GRANULARITY = 5
TARGET_COL = 'category'
CLASS_MAP = {
    'no-rain': 'No Rain', 
    'light': 'Light', 'moderate': 'Moderate', 
    'heavy': 'Heavy', 'violent': 'Violent'
}

import pandas as pd
import sys
from pathlib import Path
import joblib
import warnings
warnings.filterwarnings('ignore')

current_path = Path.cwd()
PROJECT_ROOT = None

for p in [current_path, current_path.parent, current_path.parent.parent]:
    if (p / "rainfall_acoustic_classification").exists():
        PROJECT_ROOT = p
        break

if PROJECT_ROOT:
    if str(PROJECT_ROOT) not in sys.path:
        sys.path.insert(0, str(PROJECT_ROOT))
    print(f"Project root added to sys.path")
else:
    print("ERROR: Unable to find the project root.")

from rainfall_acoustic_classification.visualization import VisualizationEngine
from rainfall_acoustic_classification.utils import get_standard_logger

# Feature Engineering
from rainfall_acoustic_classification.feature_engineering import (
    # Core modules
    ExperimentCreator, ExperimentConfig, 
    
    # Single Metric (PSD_mean) 
    SingleSelectorConfig, build_single_selector,

    # Metrics Selection
    VectorSelectorConfig, VectorSelector,
    
    # Vizualization
    plot_correlation_heatmap, plot_individual_boxplots, plot_feature_importance, plot_fisher_scores
)

# Modeling
from rainfall_acoustic_classification.modeling import (
    # Classification
    ClassifierFactory, ClassifierConfig,

    # Hyperparameter Optimization
    ModelOptimizer,TuningConfig,

    # Validation
    ModelEvaluator, ValidationConfig,

    #Vizualization
    plot_confusion_matrix_grid, plot_multiclass_pr_curve, plot_experiment_performance_heatmap
)

# Directories
DATA_DIR = PROJECT_ROOT / "data" / "processed" / DATASET
REPORTS_DIR = PROJECT_ROOT / "reports" / "vector_selector" / "experiment_3" / DATASET
MODELS_DIR = PROJECT_ROOT / "models" / "vector_selector" / "experiment_3" / DATASET

REPORTS_DIR.mkdir(parents=True, exist_ok=True)
MODELS_DIR.mkdir(parents=True, exist_ok=True)
# Out:
# Project root added to sys.path

# %% [markdown]
# # Data Loading and Mapping

# %%
df_train_metrics = pd.read_csv(DATA_DIR /  f"{DATASET}_train_metrics.csv")
df_val_metrics = pd.read_csv(DATA_DIR / f"{DATASET}_val_metrics.csv")
df_test_metrics = pd.read_csv(DATA_DIR / f"{DATASET}_test_metrics.csv")

print(f"Raw Shapes -> Train: {df_train_metrics.shape}, Val: {df_val_metrics.shape}, Test: {df_test_metrics.shape}")
# Out:
# Raw Shapes -> Train: (18953, 124), Val: (1969, 123), Test: (1969, 123)

# %%
metadata_cols = [
    'file_name', 'timestamp', 'period', 'mm_5min', 'mm_hr', 
    'category', 'recorder', 'location', 'file_path', 'extension', 
    'year', 'month', 'day', 'hour', 'minute', 'second', 'wet', 'split', 
    'should_augment', 'segment_idx', 'offset_sec', 'aug_params'
    ]

exp_config = ExperimentConfig(content=CONTENT,
                              granularity=GRANULARITY, 
                              label_col=TARGET_COL,
                              metadata_cols = metadata_cols,
                              custom_mapping=CLASS_MAP)

X_train_metrics, y_train_metrics, _ = ExperimentCreator.extract_X_y_meta(df_train_metrics, config=exp_config)
X_train, y_train = ExperimentCreator.apply_experiment_rules(X_train_metrics, y_train_metrics, config=exp_config)


X_val_metrics, y_val_metrics, _ = ExperimentCreator.extract_X_y_meta(df_val_metrics, config=exp_config)
X_val, y_val = ExperimentCreator.apply_experiment_rules(X_val_metrics, y_val_metrics, config=exp_config)


X_test_metrics, y_test_metrics, _ = ExperimentCreator.extract_X_y_meta(df_test_metrics, config=exp_config)
X_test, y_test = ExperimentCreator.apply_experiment_rules(X_test_metrics, y_test_metrics, config=exp_config)

print(f"Classes post mapping -> Train: {y_train.unique()}, Val: {y_val.unique()}, Test: {y_test.unique()}")
# Out:
# 09:32:47 - [ExperimentCreator] - INFO - Applying Smart Rules -> Content: 'dry/wet' | Granularity: 5
# 09:32:47 - [ExperimentCreator] - INFO - Applying Smart Rules -> Content: 'dry/wet' | Granularity: 5
# 09:32:47 - [ExperimentCreator] - INFO - Applying Smart Rules -> Content: 'dry/wet' | Granularity: 5
# Classes post mapping -> Train: <ArrowStringArray>
# ['No Rain', 'Moderate', 'Heavy', 'Violent', 'Light']
# Length: 5, dtype: str, Val: <ArrowStringArray>
# ['No Rain', 'Moderate', 'Heavy', 'Violent', 'Light']
# Length: 5, dtype: str, Test: <ArrowStringArray>
# ['Moderate', 'Violent', 'Light', 'No Rain', 'Heavy']
# Length: 5, dtype: str

# %% [markdown]
# # Feature Engineering (Metrics Selection and PSD)

# %%
metrics_selector_config = VectorSelectorConfig(corr_threshold=0.85, 
                                               rf_n_estimators=100, 
                                               fisher_percentile=20)
metrics_selector = VectorSelector(metrics_selector_config)

X_train_selected_metrics = metrics_selector.fit_transform(X_train, y_train)

survivors = metrics_selector.get_feature_names_out()
print(f"Original Features: {X_train.shape[1]} -> Selected: {X_train_selected_metrics.shape[1]}")
print(f"Selected ones: {survivors}")

X_val_selected_metrics = metrics_selector.transform(X_val)
X_test_selected_metrics = metrics_selector.transform(X_test)

df_feature_tracking = metrics_selector.get_metrics_report()
# Out:
# Original Features: 102 -> Selected: 19
# Selected ones: ['rms_mean' 'rms_std' 'mae' 'psd_std' 'mfcc_1' 'mfcc_3' 'mfcc_5' 'mfcc_6'
#  'mfcc_8' 'mfcc_11' 'mfcc_std' 'mfcc_var' 'wav_approx_std'
#  'wav_detail_lvl5_energy' 'wav_detail_lvl5_std' 'wav_detail_lvl4_std'
#  'wav_detail_lvl3_std' 'wav_detail_lvl2_std' 'wav_detail_lvl1_std']

# %% [markdown]
# ## Graphics

# %%
display(df_feature_tracking.head(50))
# Out:
#               Feature_Name  Fisher_Score  Gini_Importance  Survived_Pipeline
# 48                  mfcc_6   5362.423072              NaN                  1
# 85     wav_detail_lvl5_std   3694.336957              NaN                  1
# 42                  mfcc_3   3422.344783              NaN                  1
# 89     wav_detail_lvl3_std   3177.641865              NaN                  1
# 87     wav_detail_lvl4_std   3160.017258              NaN                  1
# 16                rms_mean   3042.556017              NaN                  1
# 38                  mfcc_1   2944.951921              NaN                  1
# 22                     mae   2930.950432              NaN                  1
# 79                mfcc_std   2915.982634              NaN                  1
# 46                  mfcc_5   2907.920520              NaN                  1
# 58                 mfcc_11   2787.397824              NaN                  1
# 80                mfcc_var   2743.163109              NaN                  1
# 82          wav_approx_std   2537.741761              NaN                  1
# 17                 rms_std   2516.189446              NaN                  1
# 91     wav_detail_lvl2_std   2482.586262              NaN                  1
# 84  wav_detail_lvl5_energy   2443.961620              NaN                  1
# 24                 psd_std   2438.066912              NaN                  1
# 52                  mfcc_8   2354.794872              NaN                  1
# 93     wav_detail_lvl1_std   2221.089228              NaN                  1
# 56                 mfcc_10   2207.053365              NaN                  0
# 32           spec_centroid   2136.553194              NaN                  0
# 9            anthro_energy   2115.754064              NaN                  0
# 26              spec_slope   2096.511742              NaN                  0
# 1                      ACI   2092.834147              NaN                  0
# 19                zcr_mean   2087.155363              NaN                  0
# 34            spec_rolloff   2081.658726              NaN                  0
# 27               spec_mean   1987.873953              NaN                  0
# 23                psd_mean   1987.873953              NaN                  0
# 94         wav_energy_mean   1921.699847              NaN                  0
# 78               mfcc_mean   1880.569754              NaN                  0
# 86  wav_detail_lvl4_energy   1721.405340              NaN                  0
# 50                  mfcc_7   1685.146281              NaN                  0
# 40                  mfcc_2   1647.144354              NaN                  0
# 20                 zcr_std   1629.616756              NaN                  0
# 88  wav_detail_lvl3_energy   1543.675217              NaN                  0
# 37     spec_bandwidth_mean   1515.513395              NaN                  0
# 18                 rms_var   1514.810338              NaN                  0
# 10              bio_energy   1391.986976              NaN                  0
# 83          wav_approx_var   1296.178264              NaN                  0
# 90  wav_detail_lvl2_energy   1231.025666              NaN                  0
# 66                 mfcc_15   1202.409820              NaN                  0
# 60                 mfcc_12   1162.803329              NaN                  0
# 62                 mfcc_13   1142.925625              NaN                  0
# 2                      AGI   1104.774317              NaN                  0
# 92  wav_detail_lvl1_energy   1077.193834              NaN                  0
# 0             temp_entropy   1025.134762              NaN                  0
# 81       wav_approx_energy   1021.801980              NaN                  0
# 5                      ECV    997.898267              NaN                  0
# 28                spec_std    975.387812              NaN                  0
# 25                 psd_var    975.387812              NaN                  0

# %%
display(df_feature_tracking.tail(52))
# Out:
#             Feature_Name  Fisher_Score  Gini_Importance  Survived_Pipeline
# 21               zcr_var    832.523978              NaN                  0
# 74               mfcc_19    805.560303              NaN                  0
# 7                   NDSI    636.392026              NaN                  0
# 11                    BI    515.369833              NaN                  0
# 33         spec_flatness    480.704806              NaN                  0
# 54                mfcc_9    476.367810              NaN                  0
# 64               mfcc_14    439.819378              NaN                  0
# 15         temp_kurtosis    418.358547              NaN                  0
# 6              num_peaks    408.845562              NaN                  0
# 35    spec_bandwidth_50%    407.588613              NaN                  0
# 14             temp_skew    350.802716              NaN                  0
# 8                ratioBA    337.415959              NaN                  0
# 70               mfcc_17    285.437909              NaN                  0
# 36    spec_bandwidth_90%    281.307132              NaN                  0
# 12                   ADI    279.321953              NaN                  0
# 4                    ECU    240.138571              NaN                  0
# 3                    EAS    213.865002              NaN                  0
# 72               mfcc_18    134.037795              NaN                  0
# 13                   AEI    119.828814              NaN                  0
# 29              spec_var    111.382781              NaN                  0
# 30             spec_skew    107.509526              NaN                  0
# 76               mfcc_20    100.941878              NaN                  0
# 31         spec_kurtosis     49.102902              NaN                  0
# 68               mfcc_16     33.137362              NaN                  0
# 44                mfcc_4     15.902353              NaN                  0
# 57         mfcc_delta_10      2.790349              NaN                  0
# 49          mfcc_delta_6      2.516285              NaN                  0
# 61         mfcc_delta_12      1.675163              NaN                  0
# 39          mfcc_delta_1      1.649327              NaN                  0
# 45          mfcc_delta_4      1.389674              NaN                  0
# 73         mfcc_delta_18      1.374442              NaN                  0
# 63         mfcc_delta_13      1.311705              NaN                  0
# 51          mfcc_delta_7      1.298939              NaN                  0
# 47          mfcc_delta_5      1.256943              NaN                  0
# 69         mfcc_delta_16      1.237838              NaN                  0
# 59         mfcc_delta_11      1.123175              NaN                  0
# 77         mfcc_delta_20      1.010996              NaN                  0
# 41          mfcc_delta_2      0.792695              NaN                  0
# 67         mfcc_delta_15      0.787846              NaN                  0
# 65         mfcc_delta_14      0.695931              NaN                  0
# 43          mfcc_delta_3      0.612458              NaN                  0
# 75         mfcc_delta_19      0.375117              NaN                  0
# 53          mfcc_delta_8      0.227624              NaN                  0
# 71         mfcc_delta_17      0.110492              NaN                  0
# 55          mfcc_delta_9      0.058965              NaN                  0
# 95             roughness           NaN              NaN                  0
# 96                  tfsd           NaN              NaN                  0
# 97   wav_detail_lvl1_var           NaN              NaN                  0
# 98   wav_detail_lvl2_var           NaN              NaN                  0
# 99   wav_detail_lvl3_var           NaN              NaN                  0
# 100  wav_detail_lvl4_var           NaN              NaN                  0
# 101  wav_detail_lvl5_var           NaN              NaN                  0

# %%
viz_engine = VisualizationEngine()
palette = viz_engine.get_rain_color_palette()
rain_palette = dict(list(palette.items())[:5])
exp_palette = {k: v for k, v in rain_palette.items() if k in y_train.unique()}
ordered_classes = list(exp_palette.keys())

selected_metrics = df_feature_tracking[df_feature_tracking['Survived_Pipeline'] == 1]['Feature_Name'].tolist()
X_train_fischer_metrics = X_train[selected_metrics]

# %%
plot_correlation_heatmap(
    df=X_train_fischer_metrics,
    threshold=0.85,
    title=f"Selected Metrics Correlation"
)
# Out:
# 09:13:23 - [FeaturePlots] - INFO - Generating Correlation Heatmap...

# %%
plot_individual_boxplots(
    X=X_train_fischer_metrics, 
    y=y_train, 
    color_map=rain_palette,
    class_order=ordered_classes
)
# Out:
# 09:13:34 - [FeaturePlots] - INFO - Generating Individual Boxplots for 19 features...

# %%
plot_fisher_scores(
    df_tracking=df_feature_tracking, 
    top_n=20,
    title="Fisher Score"
)
# Out:
# 09:14:09 - [FeaturePlots] - INFO - Generating Fisher Score Plot (Top 20)...

# %% [markdown]
# # Modeling

# %%
from sklearn.preprocessing import LabelEncoder
import pandas as pd

# Instancia o codificador (tradutor de Texto para Número)
le = LabelEncoder()
val_config = ValidationConfig(average_method='macro', return_report_dict=False)

# Transforma os textos ('Heavy', 'Light') em inteiros (0, 1, 2, 3, 4)
# e preserva o índice original do Pandas
y_train_enc = pd.Series(le.fit_transform(y_train), index=y_train.index, name=TARGET_COL)
y_val_enc   = pd.Series(le.transform(y_val), index=y_val.index, name=TARGET_COL)
y_test_enc  = pd.Series(le.transform(y_test), index=y_test.index, name=TARGET_COL)

print("✅ Variáveis 'y_train_enc', 'y_val_enc' e 'y_test_enc' recriadas e salvas na memória!")
print(f"Mapeamento interno: {dict(zip(le.classes_, le.transform(le.classes_)))}")
# Out:
# ✅ Variáveis 'y_train_enc', 'y_val_enc' e 'y_test_enc' recriadas e salvas na memória!
# Mapeamento interno: {'Heavy': np.int64(0), 'Light': np.int64(1), 'Moderate': np.int64(2), 'No Rain': np.int64(3), 'Violent': np.int64(4)}

# %% [markdown]
# ## Selected Metrics

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.svm import NuSVC

MAX_FEATURES = 20
top_10_features = df_feature_tracking[df_feature_tracking['Survived_Pipeline'] == 1]['Feature_Name'].head(MAX_FEATURES).tolist()

# %%
sgd_config = ClassifierConfig(model_type='sgd', random_state=42)
sgd_grid = {
    'alpha': [0.0001, 0.001], 
    'penalty': ['l2', 'elasticnet'], 
    'class_weight': ['balanced']
}
tuning_config_sgd = TuningConfig(param_grid=sgd_grid, scoring_metric='f1_macro', n_jobs=-1)
val_config = ValidationConfig(average_method='macro', return_report_dict=False)

incremental_results_sgd = []

for k in range(1, MAX_FEATURES + 1):
    current_features = top_10_features[:k]
    feature_adicionada = current_features[-1]
    
    print(f"--- Treinando com {k} Feature(s) [Adicionada agora: {feature_adicionada}] ---")
    
    # Fatiamento da matriz usando as listas de nomes
    X_tr_slice = X_train_selected_metrics[current_features]
    X_va_slice = X_val_selected_metrics[current_features]
    X_te_slice = X_test_selected_metrics[current_features]
    
    try:
        # A. Constrói o modelo
        sgd_base = ClassifierFactory.build(sgd_config)
        
        # B. Otimiza (Tuning)
        sgd_champion = ModelOptimizer.optimize(
            estimator=sgd_base, 
            X_train=X_tr_slice, 
            y_train=y_train_enc, # Usando a variável numérica que criamos para evitar erros
            X_val=X_va_slice, 
            y_val=y_val_enc, 
            config=tuning_config_sgd
        )
        
        # C. Avalia no Teste (O veredito final daquele conjunto)
        metrics_sgd = ModelEvaluator.evaluate(
            model=sgd_champion, 
            X_test=X_te_slice, 
            y_test=y_test_enc, 
            config=val_config
        )
        
        # D. Extração Segura das Métricas (Tratando possíveis mudanças no dicionário)
        f1  = metrics_sgd.get('f1_macro', metrics_sgd.get('f1_score', metrics_sgd.get('f1', 0.0)))
        acc = metrics_sgd.get('accuracy', metrics_sgd.get('accuracy_score', 0.0))
        
        incremental_results_sgd.append({
            'Dimensao': k,
            'Ultima_Feature_Inclusa': feature_adicionada,
            'F1_Macro': f1,
            'Accuracy': acc
        })
        
    except Exception as e:
        print(f"❌ Falha no passo com {k} features: {e}")

# 4. Tabela de Resultados
df_sgd_incremental = pd.DataFrame(incremental_results_sgd)
print("\n📊 Tabela de Desempenho Incremental:")
display(df_sgd_incremental)

# 5. O Gráfico Definitivo (Curva de Aprendizado por Dimensão)
plt.figure(figsize=(10, 5))
sns.lineplot(
    data=df_sgd_incremental, 
    x='Dimensao', 
    y='F1_Macro', 
    marker='o', 
    color='purple', 
    linewidth=2.5,
    markersize=8
)

plt.title("Impacto da Adição Incremental de Features Acústicas (SGD)", fontsize=14, fontweight='bold', pad=15)
plt.xlabel("Quantidade de Features Utilizadas (Top Fisher Score)", fontsize=12)
plt.ylabel("F1-Score (Macro)", fontsize=12)
plt.xticks(range(1, MAX_FEATURES + 1))
plt.grid(True, linestyle='--', alpha=0.7)
plt.tight_layout()

# Salva se a pasta REPORTS_DIR estiver definida
if 'REPORTS_DIR' in locals():
    plt.savefig(REPORTS_DIR / f"{DATASET}_E{EXP_NUM}_SGD_Incremental.pdf", dpi=300, bbox_inches='tight')

plt.show()
# Out:
# 09:15:53 - [ClassifierFactory] - INFO - CPU Scaling: Requested -1 -> Allocated 26 cores.
# --- Treinando com 1 Feature(s) [Adicionada agora: mfcc_6] ---
# 09:15:54 - [ClassifierFactory] - INFO - Building registered model architecture: SGD
# 09:15:54 - [HyperparameterTuner] - INFO - Starting Optimization Engine. Target Metric: f1_macro
# Fitting 1 folds for each of 4 candidates, totalling 4 fits
# 09:15:54 - [HyperparameterTuner] - INFO - Optimization complete. Champion Score (f1_macro) on Val Set: 0.2817
# 09:15:54 - [HyperparameterTuner] - INFO - Champion Hyperparameters: {'alpha': 0.001, 'class_weight': 'balanced', 'penalty': 'l2'}
# 09:15:54 - [HyperparameterTuner] - INFO - Refitting the champion model exclusively on the Training Set...
# 09:15:54 - [ModelEvaluator] - INFO - Executing Rigorous Stress Test (Model Evaluation)...
# 09:15:54 - [ModelEvaluator] - INFO - Test Results -> F1-Macro: 0.3112 | PR-AUC: 0.40456974177842503
# --- Treinando com 2 Feature(s) [Adicionada agora: wav_detail_lvl5_std] ---
# 09:15:54 - [ClassifierFactory] - INFO - Building registered model architecture: SGD
# 09:15:54 - [HyperparameterTuner] - INFO - Starting Optimization Engine. Target Metric: f1_macro
# Fitting 1 folds for each of 4 candidates, totalling 4 fits
# 09:15:54 - [HyperparameterTuner] - INFO - Optimization complete. Champion Score (f1_macro) on Val Set: 0.4322
# 09:15:54 - [HyperparameterTuner] - INFO - Champion Hyperparameters: {'alpha': 0.001, 'class_weight': 'balanced', 'penalty': 'elasticnet'}
# 09:15:54 - [HyperparameterTuner] - INFO - Refitting the champion model exclusively on the Training Set...
# 09:15:54 - [ModelEvaluator] - INFO - Executing Rigorous Stress Test (Model Evaluation)...
# 09:15:54 - [ModelEvaluator] - INFO - Test Results -> F1-Macro: 0.4264 | PR-AUC: 0.4695056898757771
# --- Treinando com 3 Feature(s) [Adicionada agora: mfcc_3] ---
# 09:15:54 - [ClassifierFactory] - INFO - Building registered model architecture: SGD
# 09:15:54 - [HyperparameterTuner] - INFO - Starting Optimization Engine. Target Metric: f1_macro
# Fitting 1 folds for each of 4 candidates, totalling 4 fits
# 09:15:54 - [HyperparameterTuner] - INFO - Optimization complete. Champion Score (f1_macro) on Val Set: 0.4253
# 09:15:54 - [HyperparameterTuner] - INFO - Champion Hyperparameters: {'alpha': 0.001, 'class_weight': 'balanced', 'penalty': 'elasticnet'}
# 09:15:54 - [HyperparameterTuner] - INFO - Refitting the champion model exclusively on the Training Set...
# 09:15:54 - [ModelEvaluator] - INFO - Executing Rigorous Stress Test (Model Evaluation)...
# 09:15:54 - [ModelEvaluator] - INFO - Test Results -> F1-Macro: 0.4434 | PR-AUC: 0.480252038358172
# --- Treinando com 4 Feature(s) [Adicionada agora: wav_detail_lvl3_std] ---
# 09:15:54 - [ClassifierFactory] - INFO - Building registered model architecture: SGD
# 09:15:54 - [HyperparameterTuner] - INFO - Starting Optimization Engine. Target Metric: f1_macro
# Fitting 1 folds for each of 4 candidates, totalling 4 fits
# 09:15:54 - [HyperparameterTuner] - INFO - Optimization complete. Champion Score (f1_macro) on Val Set: 0.4356
# 09:15:54 - [HyperparameterTuner] - INFO - Champion Hyperparameters: {'alpha': 0.001, 'class_weight': 'balanced', 'penalty': 'elasticnet'}
# 09:15:54 - [HyperparameterTuner] - INFO - Refitting the champion model exclusively on the Training Set...
# 09:15:54 - [ModelEvaluator] - INFO - Executing Rigorous Stress Test (Model Evaluation)...
# 09:15:54 - [ModelEvaluator] - INFO - Test Results -> F1-Macro: 0.4394 | PR-AUC: 0.4792827164140154
# --- Treinando com 5 Feature(s) [Adicionada agora: wav_detail_lvl4_std] ---
# 09:15:54 - [ClassifierFactory] - INFO - Building registered model architecture: SGD
# 09:15:54 - [HyperparameterTuner] - INFO - Starting Optimization Engine. Target Metric: f1_macro
# Fitting 1 folds for each of 4 candidates, totalling 4 fits
# 09:15:54 - [HyperparameterTuner] - INFO - Optimization complete. Champion Score (f1_macro) on Val Set: 0.4246
# 09:15:54 - [HyperparameterTuner] - INFO - Champion Hyperparameters: {'alpha': 0.001, 'class_weight': 'balanced', 'penalty': 'l2'}
# 09:15:54 - [HyperparameterTuner] - INFO - Refitting the champion model exclusively on the Training Set...
# 09:15:54 - [ModelEvaluator] - INFO - Executing Rigorous Stress Test (Model Evaluation)...
# 09:15:54 - [ModelEvaluator] - INFO - Test Results -> F1-Macro: 0.4583 | PR-AUC: 0.4814904721198253
# --- Treinando com 6 Feature(s) [Adicionada agora: rms_mean] ---
# 09:15:54 - [ClassifierFactory] - INFO - Building registered model architecture: SGD
# 09:15:54 - [HyperparameterTuner] - INFO - Starting Optimization Engine. Target Metric: f1_macro
# Fitting 1 folds for each of 4 candidates, totalling 4 fits
# 09:15:54 - [HyperparameterTuner] - INFO - Optimization complete. Champion Score (f1_macro) on Val Set: 0.4383
# 09:15:54 - [HyperparameterTuner] - INFO - Champion Hyperparameters: {'alpha': 0.001, 'class_weight': 'balanced', 'penalty': 'l2'}
# 09:15:54 - [HyperparameterTuner] - INFO - Refitting the champion model exclusively on the Training Set...
# 09:15:54 - [ModelEvaluator] - INFO - Executing Rigorous Stress Test (Model Evaluation)...
# 09:15:54 - [ModelEvaluator] - INFO - Test Results -> F1-Macro: 0.4532 | PR-AUC: 0.4725610896996832
# --- Treinando com 7 Feature(s) [Adicionada agora: mfcc_1] ---
# 09:15:54 - [ClassifierFactory] - INFO - Building registered model architecture: SGD
# 09:15:54 - [HyperparameterTuner] - INFO - Starting Optimization Engine. Target Metric: f1_macro
# Fitting 1 folds for each of 4 candidates, totalling 4 fits
# 09:15:55 - [HyperparameterTuner] - INFO - Optimization complete. Champion Score (f1_macro) on Val Set: 0.4139
# 09:15:55 - [HyperparameterTuner] - INFO - Champion Hyperparameters: {'alpha': 0.001, 'class_weight': 'balanced', 'penalty': 'l2'}
# 09:15:55 - [HyperparameterTuner] - INFO - Refitting the champion model exclusively on the Training Set...
# 09:15:55 - [ModelEvaluator] - INFO - Executing Rigorous Stress Test (Model Evaluation)...
# 09:15:55 - [ModelEvaluator] - INFO - Test Results -> F1-Macro: 0.4235 | PR-AUC: 0.4676372206316491
# --- Treinando com 8 Feature(s) [Adicionada agora: mae] ---
# 09:15:55 - [ClassifierFactory] - INFO - Building registered model architecture: SGD
# 09:15:55 - [HyperparameterTuner] - INFO - Starting Optimization Engine. Target Metric: f1_macro
# Fitting 1 folds for each of 4 candidates, totalling 4 fits
# 09:15:55 - [HyperparameterTuner] - INFO - Optimization complete. Champion Score (f1_macro) on Val Set: 0.4310
# 09:15:55 - [HyperparameterTuner] - INFO - Champion Hyperparameters: {'alpha': 0.001, 'class_weight': 'balanced', 'penalty': 'l2'}
# 09:15:55 - [HyperparameterTuner] - INFO - Refitting the champion model exclusively on the Training Set...
# 09:15:55 - [ModelEvaluator] - INFO - Executing Rigorous Stress Test (Model Evaluation)...
# 09:15:55 - [ModelEvaluator] - INFO - Test Results -> F1-Macro: 0.4376 | PR-AUC: 0.46317454924096724
# --- Treinando com 9 Feature(s) [Adicionada agora: mfcc_std] ---
# 09:15:55 - [ClassifierFactory] - INFO - Building registered model architecture: SGD
# 09:15:55 - [HyperparameterTuner] - INFO - Starting Optimization Engine. Target Metric: f1_macro
# Fitting 1 folds for each of 4 candidates, totalling 4 fits
# 09:15:55 - [HyperparameterTuner] - INFO - Optimization complete. Champion Score (f1_macro) on Val Set: 0.4253
# 09:15:55 - [HyperparameterTuner] - INFO - Champion Hyperparameters: {'alpha': 0.001, 'class_weight': 'balanced', 'penalty': 'l2'}
# 09:15:55 - [HyperparameterTuner] - INFO - Refitting the champion model exclusively on the Training Set...
# 09:15:55 - [ModelEvaluator] - INFO - Executing Rigorous Stress Test (Model Evaluation)...
# 09:15:55 - [ModelEvaluator] - INFO - Test Results -> F1-Macro: 0.4342 | PR-AUC: 0.4610201505988701
# --- Treinando com 10 Feature(s) [Adicionada agora: mfcc_5] ---
# 09:15:55 - [ClassifierFactory] - INFO - Building registered model architecture: SGD
# 09:15:55 - [HyperparameterTuner] - INFO - Starting Optimization Engine. Target Metric: f1_macro
# Fitting 1 folds for each of 4 candidates, totalling 4 fits
# 09:15:55 - [HyperparameterTuner] - INFO - Optimization complete. Champion Score (f1_macro) on Val Set: 0.4162
# 09:15:55 - [HyperparameterTuner] - INFO - Champion Hyperparameters: {'alpha': 0.001, 'class_weight': 'balanced', 'penalty': 'elasticnet'}
# 09:15:55 - [HyperparameterTuner] - INFO - Refitting the champion model exclusively on the Training Set...
# 09:15:55 - [ModelEvaluator] - INFO - Executing Rigorous Stress Test (Model Evaluation)...
# 09:15:55 - [ModelEvaluator] - INFO - Test Results -> F1-Macro: 0.4394 | PR-AUC: 0.4747384378248275
# --- Treinando com 11 Feature(s) [Adicionada agora: mfcc_11] ---
# 09:15:55 - [ClassifierFactory] - INFO - Building registered model architecture: SGD
# 09:15:55 - [HyperparameterTuner] - INFO - Starting Optimization Engine. Target Metric: f1_macro
# Fitting 1 folds for each of 4 candidates, totalling 4 fits
# 09:15:56 - [HyperparameterTuner] - INFO - Optimization complete. Champion Score (f1_macro) on Val Set: 0.4302
# 09:15:56 - [HyperparameterTuner] - INFO - Champion Hyperparameters: {'alpha': 0.001, 'class_weight': 'balanced', 'penalty': 'elasticnet'}
# 09:15:56 - [HyperparameterTuner] - INFO - Refitting the champion model exclusively on the Training Set...
# 09:15:56 - [ModelEvaluator] - INFO - Executing Rigorous Stress Test (Model Evaluation)...
# 09:15:56 - [ModelEvaluator] - INFO - Test Results -> F1-Macro: 0.4313 | PR-AUC: 0.4746128911143617
# --- Treinando com 12 Feature(s) [Adicionada agora: mfcc_var] ---
# 09:15:56 - [ClassifierFactory] - INFO - Building registered model architecture: SGD
# 09:15:56 - [HyperparameterTuner] - INFO - Starting Optimization Engine. Target Metric: f1_macro
# Fitting 1 folds for each of 4 candidates, totalling 4 fits
# 09:15:56 - [HyperparameterTuner] - INFO - Optimization complete. Champion Score (f1_macro) on Val Set: 0.4286
# 09:15:56 - [HyperparameterTuner] - INFO - Champion Hyperparameters: {'alpha': 0.001, 'class_weight': 'balanced', 'penalty': 'elasticnet'}
# 09:15:56 - [HyperparameterTuner] - INFO - Refitting the champion model exclusively on the Training Set...
# 09:15:56 - [ModelEvaluator] - INFO - Executing Rigorous Stress Test (Model Evaluation)...
# 09:15:56 - [ModelEvaluator] - INFO - Test Results -> F1-Macro: 0.4305 | PR-AUC: 0.4743732209873214
# --- Treinando com 13 Feature(s) [Adicionada agora: wav_approx_std] ---
# 09:15:56 - [ClassifierFactory] - INFO - Building registered model architecture: SGD
# 09:15:56 - [HyperparameterTuner] - INFO - Starting Optimization Engine. Target Metric: f1_macro
# Fitting 1 folds for each of 4 candidates, totalling 4 fits
# 09:15:56 - [HyperparameterTuner] - INFO - Optimization complete. Champion Score (f1_macro) on Val Set: 0.4190
# 09:15:56 - [HyperparameterTuner] - INFO - Champion Hyperparameters: {'alpha': 0.001, 'class_weight': 'balanced', 'penalty': 'l2'}
# 09:15:56 - [HyperparameterTuner] - INFO - Refitting the champion model exclusively on the Training Set...
# 09:15:56 - [ModelEvaluator] - INFO - Executing Rigorous Stress Test (Model Evaluation)...
# 09:15:56 - [ModelEvaluator] - INFO - Test Results -> F1-Macro: 0.4499 | PR-AUC: 0.47831337116618056
# --- Treinando com 14 Feature(s) [Adicionada agora: rms_std] ---
# 09:15:56 - [ClassifierFactory] - INFO - Building registered model architecture: SGD
# 09:15:56 - [HyperparameterTuner] - INFO - Starting Optimization Engine. Target Metric: f1_macro
# Fitting 1 folds for each of 4 candidates, totalling 4 fits
# 09:15:57 - [HyperparameterTuner] - INFO - Optimization complete. Champion Score (f1_macro) on Val Set: 0.4252
# 09:15:57 - [HyperparameterTuner] - INFO - Champion Hyperparameters: {'alpha': 0.001, 'class_weight': 'balanced', 'penalty': 'elasticnet'}
# 09:15:57 - [HyperparameterTuner] - INFO - Refitting the champion model exclusively on the Training Set...
# 09:15:57 - [ModelEvaluator] - INFO - Executing Rigorous Stress Test (Model Evaluation)...
# 09:15:57 - [ModelEvaluator] - INFO - Test Results -> F1-Macro: 0.4382 | PR-AUC: 0.46730969517189014
# --- Treinando com 15 Feature(s) [Adicionada agora: wav_detail_lvl2_std] ---
# 09:15:57 - [ClassifierFactory] - INFO - Building registered model architecture: SGD
# 09:15:57 - [HyperparameterTuner] - INFO - Starting Optimization Engine. Target Metric: f1_macro
# Fitting 1 folds for each of 4 candidates, totalling 4 fits
# 09:15:57 - [HyperparameterTuner] - INFO - Optimization complete. Champion Score (f1_macro) on Val Set: 0.4290
# 09:15:57 - [HyperparameterTuner] - INFO - Champion Hyperparameters: {'alpha': 0.0001, 'class_weight': 'balanced', 'penalty': 'l2'}
# 09:15:57 - [HyperparameterTuner] - INFO - Refitting the champion model exclusively on the Training Set...
# 09:15:57 - [ModelEvaluator] - INFO - Executing Rigorous Stress Test (Model Evaluation)...
# 09:15:57 - [ModelEvaluator] - INFO - Test Results -> F1-Macro: 0.4319 | PR-AUC: 0.4432816433800763
# --- Treinando com 16 Feature(s) [Adicionada agora: wav_detail_lvl5_energy] ---
# 09:15:57 - [ClassifierFactory] - INFO - Building registered model architecture: SGD
# 09:15:57 - [HyperparameterTuner] - INFO - Starting Optimization Engine. Target Metric: f1_macro
# Fitting 1 folds for each of 4 candidates, totalling 4 fits
# 09:15:57 - [HyperparameterTuner] - INFO - Optimization complete. Champion Score (f1_macro) on Val Set: 0.4324
# 09:15:57 - [HyperparameterTuner] - INFO - Champion Hyperparameters: {'alpha': 0.001, 'class_weight': 'balanced', 'penalty': 'elasticnet'}
# 09:15:57 - [HyperparameterTuner] - INFO - Refitting the champion model exclusively on the Training Set...
# 09:15:57 - [ModelEvaluator] - INFO - Executing Rigorous Stress Test (Model Evaluation)...
# 09:15:57 - [ModelEvaluator] - INFO - Test Results -> F1-Macro: 0.4407 | PR-AUC: 0.4656656333746253
# --- Treinando com 17 Feature(s) [Adicionada agora: psd_std] ---
# 09:15:57 - [ClassifierFactory] - INFO - Building registered model architecture: SGD
# 09:15:57 - [HyperparameterTuner] - INFO - Starting Optimization Engine. Target Metric: f1_macro
# Fitting 1 folds for each of 4 candidates, totalling 4 fits
# 09:15:58 - [HyperparameterTuner] - INFO - Optimization complete. Champion Score (f1_macro) on Val Set: 0.4194
# 09:15:58 - [HyperparameterTuner] - INFO - Champion Hyperparameters: {'alpha': 0.001, 'class_weight': 'balanced', 'penalty': 'elasticnet'}
# 09:15:58 - [HyperparameterTuner] - INFO - Refitting the champion model exclusively on the Training Set...
# 09:15:58 - [ModelEvaluator] - INFO - Executing Rigorous Stress Test (Model Evaluation)...
# 09:15:58 - [ModelEvaluator] - INFO - Test Results -> F1-Macro: 0.4438 | PR-AUC: 0.46809204789737213
# --- Treinando com 18 Feature(s) [Adicionada agora: mfcc_8] ---
# 09:15:58 - [ClassifierFactory] - INFO - Building registered model architecture: SGD
# 09:15:58 - [HyperparameterTuner] - INFO - Starting Optimization Engine. Target Metric: f1_macro
# Fitting 1 folds for each of 4 candidates, totalling 4 fits
# 09:15:58 - [HyperparameterTuner] - INFO - Optimization complete. Champion Score (f1_macro) on Val Set: 0.4125
# 09:15:58 - [HyperparameterTuner] - INFO - Champion Hyperparameters: {'alpha': 0.001, 'class_weight': 'balanced', 'penalty': 'l2'}
# 09:15:58 - [HyperparameterTuner] - INFO - Refitting the champion model exclusively on the Training Set...
# 09:15:58 - [ModelEvaluator] - INFO - Executing Rigorous Stress Test (Model Evaluation)...
# 09:15:58 - [ModelEvaluator] - INFO - Test Results -> F1-Macro: 0.4535 | PR-AUC: 0.4748877260341516
# --- Treinando com 19 Feature(s) [Adicionada agora: wav_detail_lvl1_std] ---
# 09:15:58 - [ClassifierFactory] - INFO - Building registered model architecture: SGD
# 09:15:58 - [HyperparameterTuner] - INFO - Starting Optimization Engine. Target Metric: f1_macro
# Fitting 1 folds for each of 4 candidates, totalling 4 fits
# 09:15:58 - [HyperparameterTuner] - INFO - Optimization complete. Champion Score (f1_macro) on Val Set: 0.4120
# 09:15:58 - [HyperparameterTuner] - INFO - Champion Hyperparameters: {'alpha': 0.001, 'class_weight': 'balanced', 'penalty': 'l2'}
# 09:15:58 - [HyperparameterTuner] - INFO - Refitting the champion model exclusively on the Training Set...
# 09:15:59 - [ModelEvaluator] - INFO - Executing Rigorous Stress Test (Model Evaluation)...
# 09:15:59 - [ModelEvaluator] - INFO - Test Results -> F1-Macro: 0.4493 | PR-AUC: 0.47492627444527835
# --- Treinando com 20 Feature(s) [Adicionada agora: wav_detail_lvl1_std] ---
# 09:15:59 - [ClassifierFactory] - INFO - Building registered model architecture: SGD
# 09:15:59 - [HyperparameterTuner] - INFO - Starting Optimization Engine. Target Metric: f1_macro
# Fitting 1 folds for each of 4 candidates, totalling 4 fits
# 09:15:59 - [HyperparameterTuner] - INFO - Optimization complete. Champion Score (f1_macro) on Val Set: 0.4120
# 09:15:59 - [HyperparameterTuner] - INFO - Champion Hyperparameters: {'alpha': 0.001, 'class_weight': 'balanced', 'penalty': 'l2'}
# 09:15:59 - [HyperparameterTuner] - INFO - Refitting the champion model exclusively on the Training Set...
# 09:15:59 - [ModelEvaluator] - INFO - Executing Rigorous Stress Test (Model Evaluation)...
# 09:15:59 - [ModelEvaluator] - INFO - Test Results -> F1-Macro: 0.4493 | PR-AUC: 0.47492627444527835
#
# 📊 Tabela de Desempenho Incremental:
#     Dimensao  Ultima_Feature_Inclusa  F1_Macro  Accuracy
# 0          1                  mfcc_6  0.311207       0.0
# 1          2     wav_detail_lvl5_std  0.426367       0.0
# 2          3                  mfcc_3  0.443422       0.0
# 3          4     wav_detail_lvl3_std  0.439443       0.0
# 4          5     wav_detail_lvl4_std  0.458294       0.0
# 5          6                rms_mean  0.453176       0.0
# 6          7                  mfcc_1  0.423545       0.0
# 7          8                     mae  0.437589       0.0
# 8          9                mfcc_std  0.434166       0.0
# 9         10                  mfcc_5  0.439394       0.0
# 10        11                 mfcc_11  0.431265       0.0
# 11        12                mfcc_var  0.430499       0.0
# 12        13          wav_approx_std  0.449920       0.0
# 13        14                 rms_std  0.438206       0.0
# 14        15     wav_detail_lvl2_std  0.431916       0.0
# 15        16  wav_detail_lvl5_energy  0.440703       0.0
# 16        17                 psd_std  0.443808       0.0
# 17        18                  mfcc_8  0.453455       0.0
# 18        19     wav_detail_lvl1_std  0.449343       0.0
# 19        20     wav_detail_lvl1_std  0.449343       0.0

# %%
# ==============================================================================
# Teste Unitário de Dimensão: Incremental Feature Scaling no LR
# ==============================================================================
print("="*60)
print("🚀 Teste de Escalonamento de Features (Incremental) - Regressão Logística (LR)")
print("="*60)

# Configurações do LR
lr_config = ClassifierConfig(model_type='lr', random_state=42)
lr_grid = {
    'C': [0.1, 1.0, 10.0], 
    'class_weight': ['balanced'], 
    'solver': ['lbfgs'], 
    'max_iter': [1000]
}
tuning_config_lr = TuningConfig(param_grid=lr_grid, scoring_metric='f1_macro', n_jobs=-1)

incremental_results_lr = []

for k in range(1, MAX_FEATURES + 1):
    current_features = top_10_features[:k]
    feature_adicionada = current_features[-1]
    print(f"--- Treinando LR com {k} Feature(s) [+ {feature_adicionada}] ---")
    
    X_tr_slice = X_train_selected_metrics[current_features]
    X_va_slice = X_val_selected_metrics[current_features]
    X_te_slice = X_test_selected_metrics[current_features]
    
    try:
        lr_base = ClassifierFactory.build(lr_config)
        lr_champion = ModelOptimizer.optimize(
            estimator=lr_base, X_train=X_tr_slice, y_train=y_train_enc, 
            X_val=X_va_slice, y_val=y_val_enc, config=tuning_config_lr
        )
        metrics_lr = ModelEvaluator.evaluate(model=lr_champion, X_test=X_te_slice, y_test=y_test_enc, config=val_config)
        
        f1  = metrics_lr.get('f1_macro', metrics_lr.get('f1_score', metrics_lr.get('f1', 0.0)))
        acc = metrics_lr.get('accuracy', metrics_lr.get('accuracy_score', 0.0))
        
        incremental_results_lr.append({'Dimensao': k, 'Ultima_Feature_Inclusa': feature_adicionada, 'F1_Macro': f1, 'Accuracy': acc})
    except Exception as e:
        print(f"❌ Falha no passo com {k} features: {e}")

# Gráfico
df_lr_incremental = pd.DataFrame(incremental_results_lr)
plt.figure(figsize=(10, 5))
sns.lineplot(data=df_lr_incremental, x='Dimensao', y='F1_Macro', marker='s', color='blue', linewidth=2.5, markersize=8)
plt.title("Impacto da Adição Incremental de Features Acústicas (Logistic Regression)", fontsize=14, fontweight='bold', pad=15)
plt.xlabel("Quantidade de Features Utilizadas (Top Fisher Score)", fontsize=12)
plt.ylabel("F1-Score (Macro)", fontsize=12)
plt.xticks(range(1, MAX_FEATURES + 1))
plt.grid(True, linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()
# Out:
# ============================================================
# 🚀 Teste de Escalonamento de Features (Incremental) - Regressão Logística (LR)
# ============================================================
# 09:16:10 - [ClassifierFactory] - INFO - CPU Scaling: Requested -1 -> Allocated 26 cores.
# --- Treinando LR com 1 Feature(s) [+ mfcc_6] ---
# 09:16:10 - [ClassifierFactory] - INFO - Building registered model architecture: LR
# 09:16:10 - [HyperparameterTuner] - INFO - Starting Optimization Engine. Target Metric: f1_macro
# Fitting 1 folds for each of 3 candidates, totalling 3 fits
# 09:16:10 - [HyperparameterTuner] - INFO - Optimization complete. Champion Score (f1_macro) on Val Set: 0.3368
# 09:16:10 - [HyperparameterTuner] - INFO - Champion Hyperparameters: {'C': 0.1, 'class_weight': 'balanced', 'max_iter': 1000, 'solver': 'lbfgs'}
# 09:16:10 - [HyperparameterTuner] - INFO - Refitting the champion model exclusively on the Training Set...
# 09:16:10 - [ModelEvaluator] - INFO - Executing Rigorous Stress Test (Model Evaluation)...
# 09:16:10 - [ModelEvaluator] - INFO - Test Results -> F1-Macro: 0.3834 | PR-AUC: 0.4031609276509596
# --- Treinando LR com 2 Feature(s) [+ wav_detail_lvl5_std] ---
# 09:16:10 - [ClassifierFactory] - INFO - Building registered model architecture: LR
# 09:16:10 - [HyperparameterTuner] - INFO - Starting Optimization Engine. Target Metric: f1_macro
# Fitting 1 folds for each of 3 candidates, totalling 3 fits
# 09:16:10 - [HyperparameterTuner] - INFO - Optimization complete. Champion Score (f1_macro) on Val Set: 0.4286
# 09:16:10 - [HyperparameterTuner] - INFO - Champion Hyperparameters: {'C': 10.0, 'class_weight': 'balanced', 'max_iter': 1000, 'solver': 'lbfgs'}
# 09:16:10 - [HyperparameterTuner] - INFO - Refitting the champion model exclusively on the Training Set...
# 09:16:10 - [ModelEvaluator] - INFO - Executing Rigorous Stress Test (Model Evaluation)...
# 09:16:10 - [ModelEvaluator] - INFO - Test Results -> F1-Macro: 0.4310 | PR-AUC: 0.46023189498647954
# --- Treinando LR com 3 Feature(s) [+ mfcc_3] ---
# 09:16:10 - [ClassifierFactory] - INFO - Building registered model architecture: LR
# 09:16:10 - [HyperparameterTuner] - INFO - Starting Optimization Engine. Target Metric: f1_macro
# Fitting 1 folds for each of 3 candidates, totalling 3 fits
# 09:16:10 - [HyperparameterTuner] - INFO - Optimization complete. Champion Score (f1_macro) on Val Set: 0.4276
# 09:16:10 - [HyperparameterTuner] - INFO - Champion Hyperparameters: {'C': 0.1, 'class_weight': 'balanced', 'max_iter': 1000, 'solver': 'lbfgs'}
# 09:16:10 - [HyperparameterTuner] - INFO - Refitting the champion model exclusively on the Training Set...
# 09:16:10 - [ModelEvaluator] - INFO - Executing Rigorous Stress Test (Model Evaluation)...
# 09:16:10 - [ModelEvaluator] - INFO - Test Results -> F1-Macro: 0.4440 | PR-AUC: 0.46979287320284746
# --- Treinando LR com 4 Feature(s) [+ wav_detail_lvl3_std] ---
# 09:16:10 - [ClassifierFactory] - INFO - Building registered model architecture: LR
# 09:16:10 - [HyperparameterTuner] - INFO - Starting Optimization Engine. Target Metric: f1_macro
# Fitting 1 folds for each of 3 candidates, totalling 3 fits
# 09:16:11 - [HyperparameterTuner] - INFO - Optimization complete. Champion Score (f1_macro) on Val Set: 0.4381
# 09:16:11 - [HyperparameterTuner] - INFO - Champion Hyperparameters: {'C': 10.0, 'class_weight': 'balanced', 'max_iter': 1000, 'solver': 'lbfgs'}
# 09:16:11 - [HyperparameterTuner] - INFO - Refitting the champion model exclusively on the Training Set...
# 09:16:11 - [ModelEvaluator] - INFO - Executing Rigorous Stress Test (Model Evaluation)...
# 09:16:11 - [ModelEvaluator] - INFO - Test Results -> F1-Macro: 0.4347 | PR-AUC: 0.4687683093979372
# --- Treinando LR com 5 Feature(s) [+ wav_detail_lvl4_std] ---
# 09:16:11 - [ClassifierFactory] - INFO - Building registered model architecture: LR
# 09:16:11 - [HyperparameterTuner] - INFO - Starting Optimization Engine. Target Metric: f1_macro
# Fitting 1 folds for each of 3 candidates, totalling 3 fits
# 09:16:11 - [HyperparameterTuner] - INFO - Optimization complete. Champion Score (f1_macro) on Val Set: 0.4284
# 09:16:11 - [HyperparameterTuner] - INFO - Champion Hyperparameters: {'C': 10.0, 'class_weight': 'balanced', 'max_iter': 1000, 'solver': 'lbfgs'}
# 09:16:11 - [HyperparameterTuner] - INFO - Refitting the champion model exclusively on the Training Set...
# 09:16:11 - [ModelEvaluator] - INFO - Executing Rigorous Stress Test (Model Evaluation)...
# 09:16:11 - [ModelEvaluator] - INFO - Test Results -> F1-Macro: 0.4389 | PR-AUC: 0.4708623021455217
# --- Treinando LR com 6 Feature(s) [+ rms_mean] ---
# 09:16:11 - [ClassifierFactory] - INFO - Building registered model architecture: LR
# 09:16:11 - [HyperparameterTuner] - INFO - Starting Optimization Engine. Target Metric: f1_macro
# Fitting 1 folds for each of 3 candidates, totalling 3 fits
# 09:16:11 - [HyperparameterTuner] - INFO - Optimization complete. Champion Score (f1_macro) on Val Set: 0.4379
# 09:16:11 - [HyperparameterTuner] - INFO - Champion Hyperparameters: {'C': 1.0, 'class_weight': 'balanced', 'max_iter': 1000, 'solver': 'lbfgs'}
# 09:16:11 - [HyperparameterTuner] - INFO - Refitting the champion model exclusively on the Training Set...
# 09:16:11 - [ModelEvaluator] - INFO - Executing Rigorous Stress Test (Model Evaluation)...
# 09:16:11 - [ModelEvaluator] - INFO - Test Results -> F1-Macro: 0.4461 | PR-AUC: 0.4720540596084549
# --- Treinando LR com 7 Feature(s) [+ mfcc_1] ---
# 09:16:11 - [ClassifierFactory] - INFO - Building registered model architecture: LR
# 09:16:11 - [HyperparameterTuner] - INFO - Starting Optimization Engine. Target Metric: f1_macro
# Fitting 1 folds for each of 3 candidates, totalling 3 fits
# 09:16:11 - [HyperparameterTuner] - INFO - Optimization complete. Champion Score (f1_macro) on Val Set: 0.4089
# 09:16:11 - [HyperparameterTuner] - INFO - Champion Hyperparameters: {'C': 0.1, 'class_weight': 'balanced', 'max_iter': 1000, 'solver': 'lbfgs'}
# 09:16:11 - [HyperparameterTuner] - INFO - Refitting the champion model exclusively on the Training Set...
# 09:16:11 - [ModelEvaluator] - INFO - Executing Rigorous Stress Test (Model Evaluation)...
# 09:16:12 - [ModelEvaluator] - INFO - Test Results -> F1-Macro: 0.4495 | PR-AUC: 0.46296440403185557
# --- Treinando LR com 8 Feature(s) [+ mae] ---
# 09:16:12 - [ClassifierFactory] - INFO - Building registered model architecture: LR
# 09:16:12 - [HyperparameterTuner] - INFO - Starting Optimization Engine. Target Metric: f1_macro
# Fitting 1 folds for each of 3 candidates, totalling 3 fits
# 09:16:12 - [HyperparameterTuner] - INFO - Optimization complete. Champion Score (f1_macro) on Val Set: 0.4028
# 09:16:12 - [HyperparameterTuner] - INFO - Champion Hyperparameters: {'C': 0.1, 'class_weight': 'balanced', 'max_iter': 1000, 'solver': 'lbfgs'}
# 09:16:12 - [HyperparameterTuner] - INFO - Refitting the champion model exclusively on the Training Set...
# 09:16:12 - [ModelEvaluator] - INFO - Executing Rigorous Stress Test (Model Evaluation)...
# 09:16:12 - [ModelEvaluator] - INFO - Test Results -> F1-Macro: 0.4496 | PR-AUC: 0.46117575416972534
# --- Treinando LR com 9 Feature(s) [+ mfcc_std] ---
# 09:16:12 - [ClassifierFactory] - INFO - Building registered model architecture: LR
# 09:16:12 - [HyperparameterTuner] - INFO - Starting Optimization Engine. Target Metric: f1_macro
# Fitting 1 folds for each of 3 candidates, totalling 3 fits
# 09:16:12 - [HyperparameterTuner] - INFO - Optimization complete. Champion Score (f1_macro) on Val Set: 0.4037
# 09:16:12 - [HyperparameterTuner] - INFO - Champion Hyperparameters: {'C': 0.1, 'class_weight': 'balanced', 'max_iter': 1000, 'solver': 'lbfgs'}
# 09:16:12 - [HyperparameterTuner] - INFO - Refitting the champion model exclusively on the Training Set...
# 09:16:12 - [ModelEvaluator] - INFO - Executing Rigorous Stress Test (Model Evaluation)...
# 09:16:13 - [ModelEvaluator] - INFO - Test Results -> F1-Macro: 0.4457 | PR-AUC: 0.4596192245539008
# --- Treinando LR com 10 Feature(s) [+ mfcc_5] ---
# 09:16:13 - [ClassifierFactory] - INFO - Building registered model architecture: LR
# 09:16:13 - [HyperparameterTuner] - INFO - Starting Optimization Engine. Target Metric: f1_macro
# Fitting 1 folds for each of 3 candidates, totalling 3 fits
# 09:16:13 - [HyperparameterTuner] - INFO - Optimization complete. Champion Score (f1_macro) on Val Set: 0.4131
# 09:16:13 - [HyperparameterTuner] - INFO - Champion Hyperparameters: {'C': 0.1, 'class_weight': 'balanced', 'max_iter': 1000, 'solver': 'lbfgs'}
# 09:16:13 - [HyperparameterTuner] - INFO - Refitting the champion model exclusively on the Training Set...
# 09:16:13 - [ModelEvaluator] - INFO - Executing Rigorous Stress Test (Model Evaluation)...
# 09:16:13 - [ModelEvaluator] - INFO - Test Results -> F1-Macro: 0.4635 | PR-AUC: 0.46609969568031967
# --- Treinando LR com 11 Feature(s) [+ mfcc_11] ---
# 09:16:13 - [ClassifierFactory] - INFO - Building registered model architecture: LR
# 09:16:13 - [HyperparameterTuner] - INFO - Starting Optimization Engine. Target Metric: f1_macro
# Fitting 1 folds for each of 3 candidates, totalling 3 fits
# 09:16:14 - [HyperparameterTuner] - INFO - Optimization complete. Champion Score (f1_macro) on Val Set: 0.4270
# 09:16:14 - [HyperparameterTuner] - INFO - Champion Hyperparameters: {'C': 1.0, 'class_weight': 'balanced', 'max_iter': 1000, 'solver': 'lbfgs'}
# 09:16:14 - [HyperparameterTuner] - INFO - Refitting the champion model exclusively on the Training Set...
# 09:16:14 - [ModelEvaluator] - INFO - Executing Rigorous Stress Test (Model Evaluation)...
# 09:16:14 - [ModelEvaluator] - INFO - Test Results -> F1-Macro: 0.4656 | PR-AUC: 0.4686821653572414
# --- Treinando LR com 12 Feature(s) [+ mfcc_var] ---
# 09:16:14 - [ClassifierFactory] - INFO - Building registered model architecture: LR
# 09:16:14 - [HyperparameterTuner] - INFO - Starting Optimization Engine. Target Metric: f1_macro
# Fitting 1 folds for each of 3 candidates, totalling 3 fits
# 09:16:14 - [HyperparameterTuner] - INFO - Optimization complete. Champion Score (f1_macro) on Val Set: 0.4265
# 09:16:14 - [HyperparameterTuner] - INFO - Champion Hyperparameters: {'C': 1.0, 'class_weight': 'balanced', 'max_iter': 1000, 'solver': 'lbfgs'}
# 09:16:14 - [HyperparameterTuner] - INFO - Refitting the champion model exclusively on the Training Set...
# 09:16:15 - [ModelEvaluator] - INFO - Executing Rigorous Stress Test (Model Evaluation)...
# 09:16:15 - [ModelEvaluator] - INFO - Test Results -> F1-Macro: 0.4691 | PR-AUC: 0.47078886516945395
# --- Treinando LR com 13 Feature(s) [+ wav_approx_std] ---
# 09:16:15 - [ClassifierFactory] - INFO - Building registered model architecture: LR
# 09:16:15 - [HyperparameterTuner] - INFO - Starting Optimization Engine. Target Metric: f1_macro
# Fitting 1 folds for each of 3 candidates, totalling 3 fits
# 09:16:15 - [HyperparameterTuner] - INFO - Optimization complete. Champion Score (f1_macro) on Val Set: 0.4373
# 09:16:15 - [HyperparameterTuner] - INFO - Champion Hyperparameters: {'C': 1.0, 'class_weight': 'balanced', 'max_iter': 1000, 'solver': 'lbfgs'}
# 09:16:15 - [HyperparameterTuner] - INFO - Refitting the champion model exclusively on the Training Set...
# 09:16:15 - [ModelEvaluator] - INFO - Executing Rigorous Stress Test (Model Evaluation)...
# 09:16:15 - [ModelEvaluator] - INFO - Test Results -> F1-Macro: 0.4596 | PR-AUC: 0.4630986886292322
# --- Treinando LR com 14 Feature(s) [+ rms_std] ---
# 09:16:15 - [ClassifierFactory] - INFO - Building registered model architecture: LR
# 09:16:15 - [HyperparameterTuner] - INFO - Starting Optimization Engine. Target Metric: f1_macro
# Fitting 1 folds for each of 3 candidates, totalling 3 fits
# 09:16:16 - [HyperparameterTuner] - INFO - Optimization complete. Champion Score (f1_macro) on Val Set: 0.4265
# 09:16:16 - [HyperparameterTuner] - INFO - Champion Hyperparameters: {'C': 1.0, 'class_weight': 'balanced', 'max_iter': 1000, 'solver': 'lbfgs'}
# 09:16:16 - [HyperparameterTuner] - INFO - Refitting the champion model exclusively on the Training Set...
# 09:16:16 - [ModelEvaluator] - INFO - Executing Rigorous Stress Test (Model Evaluation)...
# 09:16:16 - [ModelEvaluator] - INFO - Test Results -> F1-Macro: 0.4431 | PR-AUC: 0.4536612151591822
# --- Treinando LR com 15 Feature(s) [+ wav_detail_lvl2_std] ---
# 09:16:16 - [ClassifierFactory] - INFO - Building registered model architecture: LR
# 09:16:16 - [HyperparameterTuner] - INFO - Starting Optimization Engine. Target Metric: f1_macro
# Fitting 1 folds for each of 3 candidates, totalling 3 fits
# 09:16:17 - [HyperparameterTuner] - INFO - Optimization complete. Champion Score (f1_macro) on Val Set: 0.4282
# 09:16:17 - [HyperparameterTuner] - INFO - Champion Hyperparameters: {'C': 1.0, 'class_weight': 'balanced', 'max_iter': 1000, 'solver': 'lbfgs'}
# 09:16:17 - [HyperparameterTuner] - INFO - Refitting the champion model exclusively on the Training Set...
# 09:16:18 - [ModelEvaluator] - INFO - Executing Rigorous Stress Test (Model Evaluation)...
# 09:16:18 - [ModelEvaluator] - INFO - Test Results -> F1-Macro: 0.4550 | PR-AUC: 0.45140980959969684
# --- Treinando LR com 16 Feature(s) [+ wav_detail_lvl5_energy] ---
# 09:16:18 - [ClassifierFactory] - INFO - Building registered model architecture: LR
# 09:16:18 - [HyperparameterTuner] - INFO - Starting Optimization Engine. Target Metric: f1_macro
# Fitting 1 folds for each of 3 candidates, totalling 3 fits
# 09:16:19 - [HyperparameterTuner] - INFO - Optimization complete. Champion Score (f1_macro) on Val Set: 0.4359
# 09:16:19 - [HyperparameterTuner] - INFO - Champion Hyperparameters: {'C': 10.0, 'class_weight': 'balanced', 'max_iter': 1000, 'solver': 'lbfgs'}
# 09:16:19 - [HyperparameterTuner] - INFO - Refitting the champion model exclusively on the Training Set...
# 09:16:19 - [ModelEvaluator] - INFO - Executing Rigorous Stress Test (Model Evaluation)...
# 09:16:19 - [ModelEvaluator] - INFO - Test Results -> F1-Macro: 0.4662 | PR-AUC: 0.4539142716703507
# --- Treinando LR com 17 Feature(s) [+ psd_std] ---
# 09:16:19 - [ClassifierFactory] - INFO - Building registered model architecture: LR
# 09:16:19 - [HyperparameterTuner] - INFO - Starting Optimization Engine. Target Metric: f1_macro
# Fitting 1 folds for each of 3 candidates, totalling 3 fits
# 09:16:20 - [HyperparameterTuner] - INFO - Optimization complete. Champion Score (f1_macro) on Val Set: 0.4334
# 09:16:20 - [HyperparameterTuner] - INFO - Champion Hyperparameters: {'C': 10.0, 'class_weight': 'balanced', 'max_iter': 1000, 'solver': 'lbfgs'}
# 09:16:20 - [HyperparameterTuner] - INFO - Refitting the champion model exclusively on the Training Set...
# 09:16:21 - [ModelEvaluator] - INFO - Executing Rigorous Stress Test (Model Evaluation)...
# 09:16:21 - [ModelEvaluator] - INFO - Test Results -> F1-Macro: 0.4693 | PR-AUC: 0.45551575479148604
# --- Treinando LR com 18 Feature(s) [+ mfcc_8] ---
# 09:16:21 - [ClassifierFactory] - INFO - Building registered model architecture: LR
# 09:16:21 - [HyperparameterTuner] - INFO - Starting Optimization Engine. Target Metric: f1_macro
# Fitting 1 folds for each of 3 candidates, totalling 3 fits
# 09:16:22 - [HyperparameterTuner] - INFO - Optimization complete. Champion Score (f1_macro) on Val Set: 0.4402
# 09:16:22 - [HyperparameterTuner] - INFO - Champion Hyperparameters: {'C': 10.0, 'class_weight': 'balanced', 'max_iter': 1000, 'solver': 'lbfgs'}
# 09:16:22 - [HyperparameterTuner] - INFO - Refitting the champion model exclusively on the Training Set...
# 09:16:23 - [ModelEvaluator] - INFO - Executing Rigorous Stress Test (Model Evaluation)...
# 09:16:23 - [ModelEvaluator] - INFO - Test Results -> F1-Macro: 0.4679 | PR-AUC: 0.4413875812154423
# --- Treinando LR com 19 Feature(s) [+ wav_detail_lvl1_std] ---
# 09:16:23 - [ClassifierFactory] - INFO - Building registered model architecture: LR
# 09:16:23 - [HyperparameterTuner] - INFO - Starting Optimization Engine. Target Metric: f1_macro
# Fitting 1 folds for each of 3 candidates, totalling 3 fits
# 09:16:23 - [HyperparameterTuner] - INFO - Optimization complete. Champion Score (f1_macro) on Val Set: 0.4451
# 09:16:23 - [HyperparameterTuner] - INFO - Champion Hyperparameters: {'C': 10.0, 'class_weight': 'balanced', 'max_iter': 1000, 'solver': 'lbfgs'}
# 09:16:23 - [HyperparameterTuner] - INFO - Refitting the champion model exclusively on the Training Set...
# 09:16:24 - [ModelEvaluator] - INFO - Executing Rigorous Stress Test (Model Evaluation)...
# 09:16:24 - [ModelEvaluator] - INFO - Test Results -> F1-Macro: 0.4719 | PR-AUC: 0.44129886245478367
# --- Treinando LR com 20 Feature(s) [+ wav_detail_lvl1_std] ---
# 09:16:24 - [ClassifierFactory] - INFO - Building registered model architecture: LR
# 09:16:24 - [HyperparameterTuner] - INFO - Starting Optimization Engine. Target Metric: f1_macro
# Fitting 1 folds for each of 3 candidates, totalling 3 fits
# 09:16:25 - [HyperparameterTuner] - INFO - Optimization complete. Champion Score (f1_macro) on Val Set: 0.4451
# 09:16:25 - [HyperparameterTuner] - INFO - Champion Hyperparameters: {'C': 10.0, 'class_weight': 'balanced', 'max_iter': 1000, 'solver': 'lbfgs'}
# 09:16:25 - [HyperparameterTuner] - INFO - Refitting the champion model exclusively on the Training Set...
# 09:16:26 - [ModelEvaluator] - INFO - Executing Rigorous Stress Test (Model Evaluation)...
# 09:16:26 - [ModelEvaluator] - INFO - Test Results -> F1-Macro: 0.4719 | PR-AUC: 0.44129886245478367

# %%
# ==============================================================================
# Teste Unitário de Dimensão: Incremental Feature Scaling no RF
# ==============================================================================
print("="*60)
print("🚀 Teste de Escalonamento de Features (Incremental) - Random Forest (RF)")
print("="*60)

# Configurações do RF
rf_config = ClassifierConfig(model_type='rf', random_state=42)
rf_grid = {
    'n_estimators': [100, 200], 
    'max_depth': [None, 5, 10], 
    'min_samples_leaf': [1, 2]
}
tuning_config_rf = TuningConfig(param_grid=rf_grid, scoring_metric='f1_macro', n_jobs=-1)

incremental_results_rf = []

for k in range(1, MAX_FEATURES + 1):
    current_features = top_10_features[:k]
    feature_adicionada = current_features[-1]
    print(f"--- Treinando RF com {k} Feature(s) [+ {feature_adicionada}] ---")
    
    X_tr_slice = X_train_selected_metrics[current_features]
    X_va_slice = X_val_selected_metrics[current_features]
    X_te_slice = X_test_selected_metrics[current_features]
    
    try:
        rf_base = ClassifierFactory.build(rf_config)
        rf_champion = ModelOptimizer.optimize(
            estimator=rf_base, X_train=X_tr_slice, y_train=y_train_enc, 
            X_val=X_va_slice, y_val=y_val_enc, config=tuning_config_rf
        )
        metrics_rf = ModelEvaluator.evaluate(model=rf_champion, X_test=X_te_slice, y_test=y_test_enc, config=val_config)
        
        f1  = metrics_rf.get('f1_macro', metrics_rf.get('f1_score', metrics_rf.get('f1', 0.0)))
        acc = metrics_rf.get('accuracy', metrics_rf.get('accuracy_score', 0.0))
        
        incremental_results_rf.append({'Dimensao': k, 'Ultima_Feature_Inclusa': feature_adicionada, 'F1_Macro': f1, 'Accuracy': acc})
    except Exception as e:
        print(f"❌ Falha no passo com {k} features: {e}")

# Gráfico
df_rf_incremental = pd.DataFrame(incremental_results_rf)
plt.figure(figsize=(10, 5))
sns.lineplot(data=df_rf_incremental, x='Dimensao', y='F1_Macro', marker='D', color='green', linewidth=2.5, markersize=8)
plt.title("Impacto da Adição Incremental de Features Acústicas (Random Forest)", fontsize=14, fontweight='bold', pad=15)
plt.xlabel("Quantidade de Features Utilizadas (Top Fisher Score)", fontsize=12)
plt.ylabel("F1-Score (Macro)", fontsize=12)
plt.xticks(range(1, MAX_FEATURES + 1))
plt.grid(True, linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()
# Out:
# ============================================================
# 🚀 Teste de Escalonamento de Features (Incremental) - Random Forest (RF)
# ============================================================
# 09:16:34 - [ClassifierFactory] - INFO - CPU Scaling: Requested -1 -> Allocated 26 cores.
# --- Treinando RF com 1 Feature(s) [+ mfcc_6] ---
# 09:16:34 - [ClassifierFactory] - INFO - Building registered model architecture: RF
# 09:16:34 - [HyperparameterTuner] - INFO - Starting Optimization Engine. Target Metric: f1_macro
# Fitting 1 folds for each of 12 candidates, totalling 12 fits
# 09:16:35 - [HyperparameterTuner] - INFO - Optimization complete. Champion Score (f1_macro) on Val Set: 0.3313
# 09:16:35 - [HyperparameterTuner] - INFO - Champion Hyperparameters: {'max_depth': None, 'min_samples_leaf': 2, 'n_estimators': 100}
# 09:16:35 - [HyperparameterTuner] - INFO - Refitting the champion model exclusively on the Training Set...
# 09:16:35 - [ModelEvaluator] - INFO - Executing Rigorous Stress Test (Model Evaluation)...
# 09:16:35 - [ModelEvaluator] - INFO - Test Results -> F1-Macro: 0.3302 | PR-AUC: 0.3356174663035688
# --- Treinando RF com 2 Feature(s) [+ wav_detail_lvl5_std] ---
# 09:16:35 - [ClassifierFactory] - INFO - Building registered model architecture: RF
# 09:16:35 - [HyperparameterTuner] - INFO - Starting Optimization Engine. Target Metric: f1_macro
# Fitting 1 folds for each of 12 candidates, totalling 12 fits
# 09:16:37 - [HyperparameterTuner] - INFO - Optimization complete. Champion Score (f1_macro) on Val Set: 0.4088
# 09:16:37 - [HyperparameterTuner] - INFO - Champion Hyperparameters: {'max_depth': 5, 'min_samples_leaf': 1, 'n_estimators': 200}
# 09:16:37 - [HyperparameterTuner] - INFO - Refitting the champion model exclusively on the Training Set...
# 09:16:37 - [ModelEvaluator] - INFO - Executing Rigorous Stress Test (Model Evaluation)...
# 09:16:37 - [ModelEvaluator] - INFO - Test Results -> F1-Macro: 0.3934 | PR-AUC: 0.42977201770964807
# --- Treinando RF com 3 Feature(s) [+ mfcc_3] ---
# 09:16:37 - [ClassifierFactory] - INFO - Building registered model architecture: RF
# 09:16:37 - [HyperparameterTuner] - INFO - Starting Optimization Engine. Target Metric: f1_macro
# Fitting 1 folds for each of 12 candidates, totalling 12 fits
# 09:16:38 - [HyperparameterTuner] - INFO - Optimization complete. Champion Score (f1_macro) on Val Set: 0.4220
# 09:16:38 - [HyperparameterTuner] - INFO - Champion Hyperparameters: {'max_depth': 5, 'min_samples_leaf': 1, 'n_estimators': 100}
# 09:16:38 - [HyperparameterTuner] - INFO - Refitting the champion model exclusively on the Training Set...
# 09:16:38 - [ModelEvaluator] - INFO - Executing Rigorous Stress Test (Model Evaluation)...
# 09:16:38 - [ModelEvaluator] - INFO - Test Results -> F1-Macro: 0.4071 | PR-AUC: 0.44069856526430906
# --- Treinando RF com 4 Feature(s) [+ wav_detail_lvl3_std] ---
# 09:16:38 - [ClassifierFactory] - INFO - Building registered model architecture: RF
# 09:16:38 - [HyperparameterTuner] - INFO - Starting Optimization Engine. Target Metric: f1_macro
# Fitting 1 folds for each of 12 candidates, totalling 12 fits
# 09:16:40 - [HyperparameterTuner] - INFO - Optimization complete. Champion Score (f1_macro) on Val Set: 0.4196
# 09:16:40 - [HyperparameterTuner] - INFO - Champion Hyperparameters: {'max_depth': 5, 'min_samples_leaf': 1, 'n_estimators': 200}
# 09:16:40 - [HyperparameterTuner] - INFO - Refitting the champion model exclusively on the Training Set...
# 09:16:40 - [ModelEvaluator] - INFO - Executing Rigorous Stress Test (Model Evaluation)...
# 09:16:40 - [ModelEvaluator] - INFO - Test Results -> F1-Macro: 0.4147 | PR-AUC: 0.44019470719708237
# --- Treinando RF com 5 Feature(s) [+ wav_detail_lvl4_std] ---
# 09:16:40 - [ClassifierFactory] - INFO - Building registered model architecture: RF
# 09:16:40 - [HyperparameterTuner] - INFO - Starting Optimization Engine. Target Metric: f1_macro
# Fitting 1 folds for each of 12 candidates, totalling 12 fits
# 09:16:42 - [HyperparameterTuner] - INFO - Optimization complete. Champion Score (f1_macro) on Val Set: 0.4126
# 09:16:42 - [HyperparameterTuner] - INFO - Champion Hyperparameters: {'max_depth': 5, 'min_samples_leaf': 2, 'n_estimators': 200}
# 09:16:42 - [HyperparameterTuner] - INFO - Refitting the champion model exclusively on the Training Set...
# 09:16:42 - [ModelEvaluator] - INFO - Executing Rigorous Stress Test (Model Evaluation)...
# 09:16:43 - [ModelEvaluator] - INFO - Test Results -> F1-Macro: 0.4032 | PR-AUC: 0.44427529820432987
# --- Treinando RF com 6 Feature(s) [+ rms_mean] ---
# 09:16:43 - [ClassifierFactory] - INFO - Building registered model architecture: RF
# 09:16:43 - [HyperparameterTuner] - INFO - Starting Optimization Engine. Target Metric: f1_macro
# Fitting 1 folds for each of 12 candidates, totalling 12 fits
# 09:16:44 - [HyperparameterTuner] - INFO - Optimization complete. Champion Score (f1_macro) on Val Set: 0.4137
# 09:16:44 - [HyperparameterTuner] - INFO - Champion Hyperparameters: {'max_depth': 5, 'min_samples_leaf': 1, 'n_estimators': 100}
# 09:16:44 - [HyperparameterTuner] - INFO - Refitting the champion model exclusively on the Training Set...
# 09:16:44 - [ModelEvaluator] - INFO - Executing Rigorous Stress Test (Model Evaluation)...
# 09:16:45 - [ModelEvaluator] - INFO - Test Results -> F1-Macro: 0.4095 | PR-AUC: 0.44370702119996447
# --- Treinando RF com 7 Feature(s) [+ mfcc_1] ---
# 09:16:45 - [ClassifierFactory] - INFO - Building registered model architecture: RF
# 09:16:45 - [HyperparameterTuner] - INFO - Starting Optimization Engine. Target Metric: f1_macro
# Fitting 1 folds for each of 12 candidates, totalling 12 fits
# 09:16:46 - [HyperparameterTuner] - INFO - Optimization complete. Champion Score (f1_macro) on Val Set: 0.4226
# 09:16:46 - [HyperparameterTuner] - INFO - Champion Hyperparameters: {'max_depth': 10, 'min_samples_leaf': 1, 'n_estimators': 200}
# 09:16:46 - [HyperparameterTuner] - INFO - Refitting the champion model exclusively on the Training Set...
# 09:16:47 - [ModelEvaluator] - INFO - Executing Rigorous Stress Test (Model Evaluation)...
# 09:16:47 - [ModelEvaluator] - INFO - Test Results -> F1-Macro: 0.4409 | PR-AUC: 0.4374079193911836
# --- Treinando RF com 8 Feature(s) [+ mae] ---
# 09:16:47 - [ClassifierFactory] - INFO - Building registered model architecture: RF
# 09:16:47 - [HyperparameterTuner] - INFO - Starting Optimization Engine. Target Metric: f1_macro
# Fitting 1 folds for each of 12 candidates, totalling 12 fits
# 09:16:49 - [HyperparameterTuner] - INFO - Optimization complete. Champion Score (f1_macro) on Val Set: 0.4276
# 09:16:49 - [HyperparameterTuner] - INFO - Champion Hyperparameters: {'max_depth': 10, 'min_samples_leaf': 2, 'n_estimators': 100}
# 09:16:49 - [HyperparameterTuner] - INFO - Refitting the champion model exclusively on the Training Set...
# 09:16:49 - [ModelEvaluator] - INFO - Executing Rigorous Stress Test (Model Evaluation)...
# 09:16:49 - [ModelEvaluator] - INFO - Test Results -> F1-Macro: 0.4353 | PR-AUC: 0.4297445995627972
# --- Treinando RF com 9 Feature(s) [+ mfcc_std] ---
# 09:16:49 - [ClassifierFactory] - INFO - Building registered model architecture: RF
# 09:16:49 - [HyperparameterTuner] - INFO - Starting Optimization Engine. Target Metric: f1_macro
# Fitting 1 folds for each of 12 candidates, totalling 12 fits
# 09:16:51 - [HyperparameterTuner] - INFO - Optimization complete. Champion Score (f1_macro) on Val Set: 0.4285
# 09:16:51 - [HyperparameterTuner] - INFO - Champion Hyperparameters: {'max_depth': 10, 'min_samples_leaf': 1, 'n_estimators': 200}
# 09:16:51 - [HyperparameterTuner] - INFO - Refitting the champion model exclusively on the Training Set...
# 09:16:52 - [ModelEvaluator] - INFO - Executing Rigorous Stress Test (Model Evaluation)...
# 09:16:52 - [ModelEvaluator] - INFO - Test Results -> F1-Macro: 0.4386 | PR-AUC: 0.4340954912030098
# --- Treinando RF com 10 Feature(s) [+ mfcc_5] ---
# 09:16:52 - [ClassifierFactory] - INFO - Building registered model architecture: RF
# 09:16:52 - [HyperparameterTuner] - INFO - Starting Optimization Engine. Target Metric: f1_macro
# Fitting 1 folds for each of 12 candidates, totalling 12 fits
# 09:16:55 - [HyperparameterTuner] - INFO - Optimization complete. Champion Score (f1_macro) on Val Set: 0.4326
# 09:16:55 - [HyperparameterTuner] - INFO - Champion Hyperparameters: {'max_depth': None, 'min_samples_leaf': 1, 'n_estimators': 100}
# 09:16:55 - [HyperparameterTuner] - INFO - Refitting the champion model exclusively on the Training Set...
# 09:16:55 - [ModelEvaluator] - INFO - Executing Rigorous Stress Test (Model Evaluation)...
# 09:16:55 - [ModelEvaluator] - INFO - Test Results -> F1-Macro: 0.4471 | PR-AUC: 0.454994928148893
# --- Treinando RF com 11 Feature(s) [+ mfcc_11] ---
# 09:16:55 - [ClassifierFactory] - INFO - Building registered model architecture: RF
# 09:16:55 - [HyperparameterTuner] - INFO - Starting Optimization Engine. Target Metric: f1_macro
# Fitting 1 folds for each of 12 candidates, totalling 12 fits
# 09:16:58 - [HyperparameterTuner] - INFO - Optimization complete. Champion Score (f1_macro) on Val Set: 0.4571
# 09:16:58 - [HyperparameterTuner] - INFO - Champion Hyperparameters: {'max_depth': 10, 'min_samples_leaf': 1, 'n_estimators': 200}
# 09:16:58 - [HyperparameterTuner] - INFO - Refitting the champion model exclusively on the Training Set...
# 09:16:58 - [ModelEvaluator] - INFO - Executing Rigorous Stress Test (Model Evaluation)...
# 09:16:58 - [ModelEvaluator] - INFO - Test Results -> F1-Macro: 0.4594 | PR-AUC: 0.47164815598868304
# --- Treinando RF com 12 Feature(s) [+ mfcc_var] ---
# 09:16:58 - [ClassifierFactory] - INFO - Building registered model architecture: RF
# 09:16:58 - [HyperparameterTuner] - INFO - Starting Optimization Engine. Target Metric: f1_macro
# Fitting 1 folds for each of 12 candidates, totalling 12 fits
# 09:17:01 - [HyperparameterTuner] - INFO - Optimization complete. Champion Score (f1_macro) on Val Set: 0.4585
# 09:17:01 - [HyperparameterTuner] - INFO - Champion Hyperparameters: {'max_depth': 10, 'min_samples_leaf': 2, 'n_estimators': 100}
# 09:17:01 - [HyperparameterTuner] - INFO - Refitting the champion model exclusively on the Training Set...
# 09:17:01 - [ModelEvaluator] - INFO - Executing Rigorous Stress Test (Model Evaluation)...
# 09:17:01 - [ModelEvaluator] - INFO - Test Results -> F1-Macro: 0.4547 | PR-AUC: 0.4649922492276726
# --- Treinando RF com 13 Feature(s) [+ wav_approx_std] ---
# 09:17:01 - [ClassifierFactory] - INFO - Building registered model architecture: RF
# 09:17:01 - [HyperparameterTuner] - INFO - Starting Optimization Engine. Target Metric: f1_macro
# Fitting 1 folds for each of 12 candidates, totalling 12 fits
# 09:17:04 - [HyperparameterTuner] - INFO - Optimization complete. Champion Score (f1_macro) on Val Set: 0.4590
# 09:17:04 - [HyperparameterTuner] - INFO - Champion Hyperparameters: {'max_depth': 10, 'min_samples_leaf': 1, 'n_estimators': 200}
# 09:17:04 - [HyperparameterTuner] - INFO - Refitting the champion model exclusively on the Training Set...
# 09:17:05 - [ModelEvaluator] - INFO - Executing Rigorous Stress Test (Model Evaluation)...
# 09:17:05 - [ModelEvaluator] - INFO - Test Results -> F1-Macro: 0.4519 | PR-AUC: 0.4673425062059279
# --- Treinando RF com 14 Feature(s) [+ rms_std] ---
# 09:17:05 - [ClassifierFactory] - INFO - Building registered model architecture: RF
# 09:17:05 - [HyperparameterTuner] - INFO - Starting Optimization Engine. Target Metric: f1_macro
# Fitting 1 folds for each of 12 candidates, totalling 12 fits
# 09:17:08 - [HyperparameterTuner] - INFO - Optimization complete. Champion Score (f1_macro) on Val Set: 0.4549
# 09:17:08 - [HyperparameterTuner] - INFO - Champion Hyperparameters: {'max_depth': 10, 'min_samples_leaf': 1, 'n_estimators': 200}
# 09:17:08 - [HyperparameterTuner] - INFO - Refitting the champion model exclusively on the Training Set...
# 09:17:08 - [ModelEvaluator] - INFO - Executing Rigorous Stress Test (Model Evaluation)...
# 09:17:08 - [ModelEvaluator] - INFO - Test Results -> F1-Macro: 0.4561 | PR-AUC: 0.46551446585280426
# --- Treinando RF com 15 Feature(s) [+ wav_detail_lvl2_std] ---
# 09:17:08 - [ClassifierFactory] - INFO - Building registered model architecture: RF
# 09:17:08 - [HyperparameterTuner] - INFO - Starting Optimization Engine. Target Metric: f1_macro
# Fitting 1 folds for each of 12 candidates, totalling 12 fits
# 09:17:11 - [HyperparameterTuner] - INFO - Optimization complete. Champion Score (f1_macro) on Val Set: 0.4706
# 09:17:11 - [HyperparameterTuner] - INFO - Champion Hyperparameters: {'max_depth': 10, 'min_samples_leaf': 2, 'n_estimators': 100}
# 09:17:11 - [HyperparameterTuner] - INFO - Refitting the champion model exclusively on the Training Set...
# 09:17:11 - [ModelEvaluator] - INFO - Executing Rigorous Stress Test (Model Evaluation)...
# 09:17:11 - [ModelEvaluator] - INFO - Test Results -> F1-Macro: 0.4514 | PR-AUC: 0.4550956631000586
# --- Treinando RF com 16 Feature(s) [+ wav_detail_lvl5_energy] ---
# 09:17:11 - [ClassifierFactory] - INFO - Building registered model architecture: RF
# 09:17:11 - [HyperparameterTuner] - INFO - Starting Optimization Engine. Target Metric: f1_macro
# Fitting 1 folds for each of 12 candidates, totalling 12 fits
# 09:17:15 - [HyperparameterTuner] - INFO - Optimization complete. Champion Score (f1_macro) on Val Set: 0.4585
# 09:17:15 - [HyperparameterTuner] - INFO - Champion Hyperparameters: {'max_depth': 10, 'min_samples_leaf': 2, 'n_estimators': 200}
# 09:17:15 - [HyperparameterTuner] - INFO - Refitting the champion model exclusively on the Training Set...
# 09:17:15 - [ModelEvaluator] - INFO - Executing Rigorous Stress Test (Model Evaluation)...
# 09:17:15 - [ModelEvaluator] - INFO - Test Results -> F1-Macro: 0.4473 | PR-AUC: 0.46527435811030937
# --- Treinando RF com 17 Feature(s) [+ psd_std] ---
# 09:17:15 - [ClassifierFactory] - INFO - Building registered model architecture: RF
# 09:17:15 - [HyperparameterTuner] - INFO - Starting Optimization Engine. Target Metric: f1_macro
# Fitting 1 folds for each of 12 candidates, totalling 12 fits
# 09:17:19 - [HyperparameterTuner] - INFO - Optimization complete. Champion Score (f1_macro) on Val Set: 0.4631
# 09:17:19 - [HyperparameterTuner] - INFO - Champion Hyperparameters: {'max_depth': 10, 'min_samples_leaf': 1, 'n_estimators': 100}
# 09:17:19 - [HyperparameterTuner] - INFO - Refitting the champion model exclusively on the Training Set...
# 09:17:19 - [ModelEvaluator] - INFO - Executing Rigorous Stress Test (Model Evaluation)...
# 09:17:19 - [ModelEvaluator] - INFO - Test Results -> F1-Macro: 0.4457 | PR-AUC: 0.4612390959094846
# --- Treinando RF com 18 Feature(s) [+ mfcc_8] ---
# 09:17:19 - [ClassifierFactory] - INFO - Building registered model architecture: RF
# 09:17:19 - [HyperparameterTuner] - INFO - Starting Optimization Engine. Target Metric: f1_macro
# Fitting 1 folds for each of 12 candidates, totalling 12 fits
# 09:17:23 - [HyperparameterTuner] - INFO - Optimization complete. Champion Score (f1_macro) on Val Set: 0.4666
# 09:17:23 - [HyperparameterTuner] - INFO - Champion Hyperparameters: {'max_depth': None, 'min_samples_leaf': 1, 'n_estimators': 100}
# 09:17:23 - [HyperparameterTuner] - INFO - Refitting the champion model exclusively on the Training Set...
# 09:17:23 - [ModelEvaluator] - INFO - Executing Rigorous Stress Test (Model Evaluation)...
# 09:17:23 - [ModelEvaluator] - INFO - Test Results -> F1-Macro: 0.4699 | PR-AUC: 0.46633344015388856
# --- Treinando RF com 19 Feature(s) [+ wav_detail_lvl1_std] ---
# 09:17:23 - [ClassifierFactory] - INFO - Building registered model architecture: RF
# 09:17:23 - [HyperparameterTuner] - INFO - Starting Optimization Engine. Target Metric: f1_macro
# Fitting 1 folds for each of 12 candidates, totalling 12 fits
# 09:17:27 - [HyperparameterTuner] - INFO - Optimization complete. Champion Score (f1_macro) on Val Set: 0.4724
# 09:17:27 - [HyperparameterTuner] - INFO - Champion Hyperparameters: {'max_depth': None, 'min_samples_leaf': 2, 'n_estimators': 200}
# 09:17:27 - [HyperparameterTuner] - INFO - Refitting the champion model exclusively on the Training Set...
# 09:17:27 - [ModelEvaluator] - INFO - Executing Rigorous Stress Test (Model Evaluation)...
# 09:17:28 - [ModelEvaluator] - INFO - Test Results -> F1-Macro: 0.4603 | PR-AUC: 0.4707788911677812
# --- Treinando RF com 20 Feature(s) [+ wav_detail_lvl1_std] ---
# 09:17:28 - [ClassifierFactory] - INFO - Building registered model architecture: RF
# 09:17:28 - [HyperparameterTuner] - INFO - Starting Optimization Engine. Target Metric: f1_macro
# Fitting 1 folds for each of 12 candidates, totalling 12 fits
# 09:17:31 - [HyperparameterTuner] - INFO - Optimization complete. Champion Score (f1_macro) on Val Set: 0.4724
# 09:17:31 - [HyperparameterTuner] - INFO - Champion Hyperparameters: {'max_depth': None, 'min_samples_leaf': 2, 'n_estimators': 200}
# 09:17:31 - [HyperparameterTuner] - INFO - Refitting the champion model exclusively on the Training Set...
# 09:17:32 - [ModelEvaluator] - INFO - Executing Rigorous Stress Test (Model Evaluation)...
# 09:17:32 - [ModelEvaluator] - INFO - Test Results -> F1-Macro: 0.4603 | PR-AUC: 0.4707788798190908

# %%
# ==============================================================================
# Teste Unitário de Dimensão: Incremental Feature Scaling no XGBoost
# ==============================================================================
print("="*60)
print("🚀 Teste de Escalonamento de Features (Incremental) - XGBoost (XGB)")
print("="*60)

# Configurações do XGBoost
xgb_config = ClassifierConfig(model_type='xgb', random_state=42)
xgb_grid = {
    'n_estimators': [100, 200], 
    'max_depth': [3, 5], 
    'learning_rate': [0.01, 0.1]
}
tuning_config_xgb = TuningConfig(param_grid=xgb_grid, scoring_metric='f1_macro', n_jobs=-1)

incremental_results_xgb = []

for k in range(1, MAX_FEATURES + 1):
    current_features = top_10_features[:k]
    feature_adicionada = current_features[-1]
    print(f"--- Treinando XGB com {k} Feature(s) [+ {feature_adicionada}] ---")
    
    X_tr_slice = X_train_selected_metrics[current_features]
    X_va_slice = X_val_selected_metrics[current_features]
    X_te_slice = X_test_selected_metrics[current_features]
    
    try:
        xgb_base = ClassifierFactory.build(xgb_config)
        xgb_champion = ModelOptimizer.optimize(
            estimator=xgb_base, X_train=X_tr_slice, y_train=y_train_enc, 
            X_val=X_va_slice, y_val=y_val_enc, config=tuning_config_xgb
        )
        metrics_xgb = ModelEvaluator.evaluate(model=xgb_champion, X_test=X_te_slice, y_test=y_test_enc, config=val_config)
        
        f1  = metrics_xgb.get('f1_macro', metrics_xgb.get('f1_score', metrics_xgb.get('f1', 0.0)))
        acc = metrics_xgb.get('accuracy', metrics_xgb.get('accuracy_score', 0.0))
        
        incremental_results_xgb.append({'Dimensao': k, 'Ultima_Feature_Inclusa': feature_adicionada, 'F1_Macro': f1, 'Accuracy': acc})
    except Exception as e:
        print(f"❌ Falha no passo com {k} features: {e}")

# Gráfico
df_xgb_incremental = pd.DataFrame(incremental_results_xgb)
plt.figure(figsize=(10, 5))
sns.lineplot(data=df_xgb_incremental, x='Dimensao', y='F1_Macro', marker='^', color='orange', linewidth=2.5, markersize=8)
plt.title("Impacto da Adição Incremental de Features Acústicas (XGBoost)", fontsize=14, fontweight='bold', pad=15)
plt.xlabel("Quantidade de Features Utilizadas (Top Fisher Score)", fontsize=12)
plt.ylabel("F1-Score (Macro)", fontsize=12)
plt.xticks(range(1, MAX_FEATURES + 1))
plt.grid(True, linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()
# Out:
# ============================================================
# 🚀 Teste de Escalonamento de Features (Incremental) - XGBoost (XGB)
# ============================================================
# 09:17:32 - [ClassifierFactory] - INFO - CPU Scaling: Requested -1 -> Allocated 26 cores.
# --- Treinando XGB com 1 Feature(s) [+ mfcc_6] ---
# 09:17:32 - [ClassifierFactory] - INFO - Building registered model architecture: XGB
# 09:17:32 - [HyperparameterTuner] - INFO - Starting Optimization Engine. Target Metric: f1_macro
# Fitting 1 folds for each of 8 candidates, totalling 8 fits
# 09:17:33 - [HyperparameterTuner] - INFO - Optimization complete. Champion Score (f1_macro) on Val Set: 0.3023
# 09:17:33 - [HyperparameterTuner] - INFO - Champion Hyperparameters: {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 200}
# 09:17:33 - [HyperparameterTuner] - INFO - Refitting the champion model exclusively on the Training Set...
# 09:17:33 - [ModelEvaluator] - INFO - Executing Rigorous Stress Test (Model Evaluation)...
# 09:17:33 - [ModelEvaluator] - INFO - Test Results -> F1-Macro: 0.3542 | PR-AUC: 0.39680231673318106
# --- Treinando XGB com 2 Feature(s) [+ wav_detail_lvl5_std] ---
# 09:17:33 - [ClassifierFactory] - INFO - Building registered model architecture: XGB
# 09:17:33 - [HyperparameterTuner] - INFO - Starting Optimization Engine. Target Metric: f1_macro
# Fitting 1 folds for each of 8 candidates, totalling 8 fits
# 09:17:34 - [HyperparameterTuner] - INFO - Optimization complete. Champion Score (f1_macro) on Val Set: 0.3938
# 09:17:34 - [HyperparameterTuner] - INFO - Champion Hyperparameters: {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 100}
# 09:17:34 - [HyperparameterTuner] - INFO - Refitting the champion model exclusively on the Training Set...
# 09:17:34 - [ModelEvaluator] - INFO - Executing Rigorous Stress Test (Model Evaluation)...
# 09:17:34 - [ModelEvaluator] - INFO - Test Results -> F1-Macro: 0.3897 | PR-AUC: 0.42097069405117377
# --- Treinando XGB com 3 Feature(s) [+ mfcc_3] ---
# 09:17:34 - [ClassifierFactory] - INFO - Building registered model architecture: XGB
# 09:17:34 - [HyperparameterTuner] - INFO - Starting Optimization Engine. Target Metric: f1_macro
# Fitting 1 folds for each of 8 candidates, totalling 8 fits
# 09:17:35 - [HyperparameterTuner] - INFO - Optimization complete. Champion Score (f1_macro) on Val Set: 0.4003
# 09:17:35 - [HyperparameterTuner] - INFO - Champion Hyperparameters: {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 100}
# 09:17:35 - [HyperparameterTuner] - INFO - Refitting the champion model exclusively on the Training Set...
# 09:17:35 - [ModelEvaluator] - INFO - Executing Rigorous Stress Test (Model Evaluation)...
# 09:17:35 - [ModelEvaluator] - INFO - Test Results -> F1-Macro: 0.3924 | PR-AUC: 0.4277840687767068
# --- Treinando XGB com 4 Feature(s) [+ wav_detail_lvl3_std] ---
# 09:17:35 - [ClassifierFactory] - INFO - Building registered model architecture: XGB
# 09:17:35 - [HyperparameterTuner] - INFO - Starting Optimization Engine. Target Metric: f1_macro
# Fitting 1 folds for each of 8 candidates, totalling 8 fits
# 09:17:36 - [HyperparameterTuner] - INFO - Optimization complete. Champion Score (f1_macro) on Val Set: 0.3970
# 09:17:36 - [HyperparameterTuner] - INFO - Champion Hyperparameters: {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 200}
# 09:17:36 - [HyperparameterTuner] - INFO - Refitting the champion model exclusively on the Training Set...
# 09:17:36 - [ModelEvaluator] - INFO - Executing Rigorous Stress Test (Model Evaluation)...
# 09:17:36 - [ModelEvaluator] - INFO - Test Results -> F1-Macro: 0.3716 | PR-AUC: 0.4265527321726494
# --- Treinando XGB com 5 Feature(s) [+ wav_detail_lvl4_std] ---
# 09:17:36 - [ClassifierFactory] - INFO - Building registered model architecture: XGB
# 09:17:36 - [HyperparameterTuner] - INFO - Starting Optimization Engine. Target Metric: f1_macro
# Fitting 1 folds for each of 8 candidates, totalling 8 fits
# 09:17:37 - [HyperparameterTuner] - INFO - Optimization complete. Champion Score (f1_macro) on Val Set: 0.4023
# 09:17:37 - [HyperparameterTuner] - INFO - Champion Hyperparameters: {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 100}
# 09:17:37 - [HyperparameterTuner] - INFO - Refitting the champion model exclusively on the Training Set...
# 09:17:37 - [ModelEvaluator] - INFO - Executing Rigorous Stress Test (Model Evaluation)...
# 09:17:37 - [ModelEvaluator] - INFO - Test Results -> F1-Macro: 0.3830 | PR-AUC: 0.43085967072604675
# --- Treinando XGB com 6 Feature(s) [+ rms_mean] ---
# 09:17:37 - [ClassifierFactory] - INFO - Building registered model architecture: XGB
# 09:17:37 - [HyperparameterTuner] - INFO - Starting Optimization Engine. Target Metric: f1_macro
# Fitting 1 folds for each of 8 candidates, totalling 8 fits
# 09:17:38 - [HyperparameterTuner] - INFO - Optimization complete. Champion Score (f1_macro) on Val Set: 0.4036
# 09:17:38 - [HyperparameterTuner] - INFO - Champion Hyperparameters: {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 100}
# 09:17:38 - [HyperparameterTuner] - INFO - Refitting the champion model exclusively on the Training Set...
# 09:17:39 - [ModelEvaluator] - INFO - Executing Rigorous Stress Test (Model Evaluation)...
# 09:17:39 - [ModelEvaluator] - INFO - Test Results -> F1-Macro: 0.3679 | PR-AUC: 0.42710911613171987
# --- Treinando XGB com 7 Feature(s) [+ mfcc_1] ---
# 09:17:39 - [ClassifierFactory] - INFO - Building registered model architecture: XGB
# 09:17:39 - [HyperparameterTuner] - INFO - Starting Optimization Engine. Target Metric: f1_macro
# Fitting 1 folds for each of 8 candidates, totalling 8 fits
# 09:17:40 - [HyperparameterTuner] - INFO - Optimization complete. Champion Score (f1_macro) on Val Set: 0.4065
# 09:17:40 - [HyperparameterTuner] - INFO - Champion Hyperparameters: {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 100}
# 09:17:40 - [HyperparameterTuner] - INFO - Refitting the champion model exclusively on the Training Set...
# 09:17:40 - [ModelEvaluator] - INFO - Executing Rigorous Stress Test (Model Evaluation)...
# 09:17:40 - [ModelEvaluator] - INFO - Test Results -> F1-Macro: 0.3788 | PR-AUC: 0.42670072329540326
# --- Treinando XGB com 8 Feature(s) [+ mae] ---
# 09:17:40 - [ClassifierFactory] - INFO - Building registered model architecture: XGB
# 09:17:40 - [HyperparameterTuner] - INFO - Starting Optimization Engine. Target Metric: f1_macro
# Fitting 1 folds for each of 8 candidates, totalling 8 fits
# 09:17:41 - [HyperparameterTuner] - INFO - Optimization complete. Champion Score (f1_macro) on Val Set: 0.4050
# 09:17:41 - [HyperparameterTuner] - INFO - Champion Hyperparameters: {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 100}
# 09:17:41 - [HyperparameterTuner] - INFO - Refitting the champion model exclusively on the Training Set...
# 09:17:41 - [ModelEvaluator] - INFO - Executing Rigorous Stress Test (Model Evaluation)...
# 09:17:41 - [ModelEvaluator] - INFO - Test Results -> F1-Macro: 0.3908 | PR-AUC: 0.4242018686525233
# --- Treinando XGB com 9 Feature(s) [+ mfcc_std] ---
# 09:17:41 - [ClassifierFactory] - INFO - Building registered model architecture: XGB
# 09:17:41 - [HyperparameterTuner] - INFO - Starting Optimization Engine. Target Metric: f1_macro
# Fitting 1 folds for each of 8 candidates, totalling 8 fits
# 09:17:43 - [HyperparameterTuner] - INFO - Optimization complete. Champion Score (f1_macro) on Val Set: 0.4015
# 09:17:43 - [HyperparameterTuner] - INFO - Champion Hyperparameters: {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 200}
# 09:17:43 - [HyperparameterTuner] - INFO - Refitting the champion model exclusively on the Training Set...
# 09:17:43 - [ModelEvaluator] - INFO - Executing Rigorous Stress Test (Model Evaluation)...
# 09:17:43 - [ModelEvaluator] - INFO - Test Results -> F1-Macro: 0.4035 | PR-AUC: 0.42059923593347326
# --- Treinando XGB com 10 Feature(s) [+ mfcc_5] ---
# 09:17:43 - [ClassifierFactory] - INFO - Building registered model architecture: XGB
# 09:17:43 - [HyperparameterTuner] - INFO - Starting Optimization Engine. Target Metric: f1_macro
# Fitting 1 folds for each of 8 candidates, totalling 8 fits
# 09:17:45 - [HyperparameterTuner] - INFO - Optimization complete. Champion Score (f1_macro) on Val Set: 0.4259
# 09:17:45 - [HyperparameterTuner] - INFO - Champion Hyperparameters: {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 100}
# 09:17:45 - [HyperparameterTuner] - INFO - Refitting the champion model exclusively on the Training Set...
# 09:17:45 - [ModelEvaluator] - INFO - Executing Rigorous Stress Test (Model Evaluation)...
# 09:17:45 - [ModelEvaluator] - INFO - Test Results -> F1-Macro: 0.4337 | PR-AUC: 0.44630166162258844
# --- Treinando XGB com 11 Feature(s) [+ mfcc_11] ---
# 09:17:45 - [ClassifierFactory] - INFO - Building registered model architecture: XGB
# 09:17:45 - [HyperparameterTuner] - INFO - Starting Optimization Engine. Target Metric: f1_macro
# Fitting 1 folds for each of 8 candidates, totalling 8 fits
# 09:17:46 - [HyperparameterTuner] - INFO - Optimization complete. Champion Score (f1_macro) on Val Set: 0.4318
# 09:17:46 - [HyperparameterTuner] - INFO - Champion Hyperparameters: {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 100}
# 09:17:46 - [HyperparameterTuner] - INFO - Refitting the champion model exclusively on the Training Set...
# 09:17:47 - [ModelEvaluator] - INFO - Executing Rigorous Stress Test (Model Evaluation)...
# 09:17:47 - [ModelEvaluator] - INFO - Test Results -> F1-Macro: 0.4559 | PR-AUC: 0.46569755184409267
# --- Treinando XGB com 12 Feature(s) [+ mfcc_var] ---
# 09:17:47 - [ClassifierFactory] - INFO - Building registered model architecture: XGB
# 09:17:47 - [HyperparameterTuner] - INFO - Starting Optimization Engine. Target Metric: f1_macro
# Fitting 1 folds for each of 8 candidates, totalling 8 fits
# 09:17:48 - [HyperparameterTuner] - INFO - Optimization complete. Champion Score (f1_macro) on Val Set: 0.4318
# 09:17:48 - [HyperparameterTuner] - INFO - Champion Hyperparameters: {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 100}
# 09:17:48 - [HyperparameterTuner] - INFO - Refitting the champion model exclusively on the Training Set...
# 09:17:48 - [ModelEvaluator] - INFO - Executing Rigorous Stress Test (Model Evaluation)...
# 09:17:48 - [ModelEvaluator] - INFO - Test Results -> F1-Macro: 0.4559 | PR-AUC: 0.46569755184409267
# --- Treinando XGB com 13 Feature(s) [+ wav_approx_std] ---
# 09:17:48 - [ClassifierFactory] - INFO - Building registered model architecture: XGB
# 09:17:48 - [HyperparameterTuner] - INFO - Starting Optimization Engine. Target Metric: f1_macro
# Fitting 1 folds for each of 8 candidates, totalling 8 fits
# 09:17:50 - [HyperparameterTuner] - INFO - Optimization complete. Champion Score (f1_macro) on Val Set: 0.4373
# 09:17:50 - [HyperparameterTuner] - INFO - Champion Hyperparameters: {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 100}
# 09:17:50 - [HyperparameterTuner] - INFO - Refitting the champion model exclusively on the Training Set...
# 09:17:50 - [ModelEvaluator] - INFO - Executing Rigorous Stress Test (Model Evaluation)...
# 09:17:50 - [ModelEvaluator] - INFO - Test Results -> F1-Macro: 0.4532 | PR-AUC: 0.4619008720550221
# --- Treinando XGB com 14 Feature(s) [+ rms_std] ---
# 09:17:50 - [ClassifierFactory] - INFO - Building registered model architecture: XGB
# 09:17:50 - [HyperparameterTuner] - INFO - Starting Optimization Engine. Target Metric: f1_macro
# Fitting 1 folds for each of 8 candidates, totalling 8 fits
# 09:17:52 - [HyperparameterTuner] - INFO - Optimization complete. Champion Score (f1_macro) on Val Set: 0.4286
# 09:17:52 - [HyperparameterTuner] - INFO - Champion Hyperparameters: {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 200}
# 09:17:52 - [HyperparameterTuner] - INFO - Refitting the champion model exclusively on the Training Set...
# 09:17:53 - [ModelEvaluator] - INFO - Executing Rigorous Stress Test (Model Evaluation)...
# 09:17:53 - [ModelEvaluator] - INFO - Test Results -> F1-Macro: 0.4613 | PR-AUC: 0.46764599132931756
# --- Treinando XGB com 15 Feature(s) [+ wav_detail_lvl2_std] ---
# 09:17:53 - [ClassifierFactory] - INFO - Building registered model architecture: XGB
# 09:17:53 - [HyperparameterTuner] - INFO - Starting Optimization Engine. Target Metric: f1_macro
# Fitting 1 folds for each of 8 candidates, totalling 8 fits
# 09:17:54 - [HyperparameterTuner] - INFO - Optimization complete. Champion Score (f1_macro) on Val Set: 0.4295
# 09:17:54 - [HyperparameterTuner] - INFO - Champion Hyperparameters: {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 200}
# 09:17:54 - [HyperparameterTuner] - INFO - Refitting the champion model exclusively on the Training Set...
# 09:17:55 - [ModelEvaluator] - INFO - Executing Rigorous Stress Test (Model Evaluation)...
# 09:17:55 - [ModelEvaluator] - INFO - Test Results -> F1-Macro: 0.4322 | PR-AUC: 0.45638084389727174
# --- Treinando XGB com 16 Feature(s) [+ wav_detail_lvl5_energy] ---
# 09:17:55 - [ClassifierFactory] - INFO - Building registered model architecture: XGB
# 09:17:55 - [HyperparameterTuner] - INFO - Starting Optimization Engine. Target Metric: f1_macro
# Fitting 1 folds for each of 8 candidates, totalling 8 fits
# 09:17:57 - [HyperparameterTuner] - INFO - Optimization complete. Champion Score (f1_macro) on Val Set: 0.4269
# 09:17:57 - [HyperparameterTuner] - INFO - Champion Hyperparameters: {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 200}
# 09:17:57 - [HyperparameterTuner] - INFO - Refitting the champion model exclusively on the Training Set...
# 09:17:57 - [ModelEvaluator] - INFO - Executing Rigorous Stress Test (Model Evaluation)...
# 09:17:57 - [ModelEvaluator] - INFO - Test Results -> F1-Macro: 0.4732 | PR-AUC: 0.4752546558923611
# --- Treinando XGB com 17 Feature(s) [+ psd_std] ---
# 09:17:57 - [ClassifierFactory] - INFO - Building registered model architecture: XGB
# 09:17:57 - [HyperparameterTuner] - INFO - Starting Optimization Engine. Target Metric: f1_macro
# Fitting 1 folds for each of 8 candidates, totalling 8 fits
# 09:17:59 - [HyperparameterTuner] - INFO - Optimization complete. Champion Score (f1_macro) on Val Set: 0.4287
# 09:17:59 - [HyperparameterTuner] - INFO - Champion Hyperparameters: {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 100}
# 09:17:59 - [HyperparameterTuner] - INFO - Refitting the champion model exclusively on the Training Set...
# 09:17:59 - [ModelEvaluator] - INFO - Executing Rigorous Stress Test (Model Evaluation)...
# 09:17:59 - [ModelEvaluator] - INFO - Test Results -> F1-Macro: 0.4576 | PR-AUC: 0.46128133527252013
# --- Treinando XGB com 18 Feature(s) [+ mfcc_8] ---
# 09:17:59 - [ClassifierFactory] - INFO - Building registered model architecture: XGB
# 09:17:59 - [HyperparameterTuner] - INFO - Starting Optimization Engine. Target Metric: f1_macro
# Fitting 1 folds for each of 8 candidates, totalling 8 fits
# 09:18:01 - [HyperparameterTuner] - INFO - Optimization complete. Champion Score (f1_macro) on Val Set: 0.4531
# 09:18:01 - [HyperparameterTuner] - INFO - Champion Hyperparameters: {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 200}
# 09:18:01 - [HyperparameterTuner] - INFO - Refitting the champion model exclusively on the Training Set...
# 09:18:02 - [ModelEvaluator] - INFO - Executing Rigorous Stress Test (Model Evaluation)...
# 09:18:02 - [ModelEvaluator] - INFO - Test Results -> F1-Macro: 0.4433 | PR-AUC: 0.477732125352394
# --- Treinando XGB com 19 Feature(s) [+ wav_detail_lvl1_std] ---
# 09:18:02 - [ClassifierFactory] - INFO - Building registered model architecture: XGB
# 09:18:02 - [HyperparameterTuner] - INFO - Starting Optimization Engine. Target Metric: f1_macro
# Fitting 1 folds for each of 8 candidates, totalling 8 fits
# 09:18:04 - [HyperparameterTuner] - INFO - Optimization complete. Champion Score (f1_macro) on Val Set: 0.4541
# 09:18:04 - [HyperparameterTuner] - INFO - Champion Hyperparameters: {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 100}
# 09:18:04 - [HyperparameterTuner] - INFO - Refitting the champion model exclusively on the Training Set...
# 09:18:04 - [ModelEvaluator] - INFO - Executing Rigorous Stress Test (Model Evaluation)...
# 09:18:04 - [ModelEvaluator] - INFO - Test Results -> F1-Macro: 0.4508 | PR-AUC: 0.4683213405628022
# --- Treinando XGB com 20 Feature(s) [+ wav_detail_lvl1_std] ---
# 09:18:04 - [ClassifierFactory] - INFO - Building registered model architecture: XGB
# 09:18:04 - [HyperparameterTuner] - INFO - Starting Optimization Engine. Target Metric: f1_macro
# Fitting 1 folds for each of 8 candidates, totalling 8 fits
# 09:18:06 - [HyperparameterTuner] - INFO - Optimization complete. Champion Score (f1_macro) on Val Set: 0.4541
# 09:18:06 - [HyperparameterTuner] - INFO - Champion Hyperparameters: {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 100}
# 09:18:06 - [HyperparameterTuner] - INFO - Refitting the champion model exclusively on the Training Set...
# 09:18:07 - [ModelEvaluator] - INFO - Executing Rigorous Stress Test (Model Evaluation)...
# 09:18:07 - [ModelEvaluator] - INFO - Test Results -> F1-Macro: 0.4508 | PR-AUC: 0.4683213405628022

# %%
# ==============================================================================
# Teste Unitário de Dimensão: Incremental Feature Scaling (Bare-Metal Otimizado)
# ==============================================================================
incremental_results_master = []

# Loop Incremental do Doutorando
for k in range(1, MAX_FEATURES + 1):
    current_features = top_10_features[:k]
    feature_adicionada = current_features[-1]
    
    print(f"--- Treinando Master Model com {k} Feature(s) [+ {feature_adicionada}] ---")
    
    # Fatiamento DIRETO (Sem necessidade de carregar X_val)
    X_tr_slice = X_train_selected_metrics[current_features]
    X_te_slice = X_test_selected_metrics[current_features]
    
    try:
        # 1. Instanciação Direta (Bypass do Otimizador e da Factory)
        clf_master = NuSVC(
            kernel='poly', 
            degree=3, 
            coef0=1.0, 
            nu=0.5, 
            gamma='scale', 
            class_weight='balanced', 
            probability=True, 
            random_state=42
        )
        
        # 2. Treinamento Direto no Conjunto de Treino
        clf_master.fit(X_tr_slice, y_train_enc)
        
        # 3. Avaliação Inviolável no Conjunto de Teste
        metrics_master = ModelEvaluator.evaluate(
            model=clf_master, 
            X_test=X_te_slice, 
            y_test=y_test_enc, 
            config=val_config
        )
        
        # Puxando o F1 Macro com segurança
        f1 = metrics_master.get('f1_macro', metrics_master.get('f1_score', metrics_master.get('f1', 0.0)))
        
        incremental_results_master.append({
            'Dimensao': k,
            'Ultima_Feature_Inclusa': feature_adicionada,
            'F1_Macro': f1
        })
        
    except Exception as e:
        print(f"❌ Falha no passo com {k} features: {e}")
        # Se 'nu=0.5' for impossível para as primeiras dimensões (ex: 1, 2 ou 3 features),
        # o try/except absorve o erro 'infeasible' e o gráfico plotará a curva a partir 
        # da dimensão onde a matemática passa a funcionar.

# ------------------------------------------------------------------------------
# Resultados e Gráfico
# ------------------------------------------------------------------------------
df_master_incremental = pd.DataFrame(incremental_results_master)
print("\n📊 Tabela de Desempenho Incremental (Master Model):")
display(df_master_incremental)

plt.figure(figsize=(10, 5))
sns.lineplot(
    data=df_master_incremental, 
    x='Dimensao', 
    y='F1_Macro', 
    marker='*', 
    color='gold', 
    markeredgecolor='black',
    linewidth=3.0,
    markersize=14
)

plt.title("Impacto da Adição Incremental de Features no Modelo Master (NuSVC Poly Grau 3)", fontsize=14, fontweight='bold', pad=15)
plt.xlabel("Quantidade de Features Acústicas Utilizadas", fontsize=12)
plt.ylabel("F1-Score (Macro)", fontsize=12)

# Força o eixo X a exibir os números corretos baseados nas dimensões que rodaram com sucesso
if not df_master_incremental.empty:
    plt.xticks(df_master_incremental['Dimensao'].tolist())
    
plt.grid(True, linestyle='--', alpha=0.7)
plt.tight_layout()

if 'REPORTS_DIR' in locals():
    plt.savefig(REPORTS_DIR / f"{DATASET}_E{EXP_NUM}_MasterModel_Incremental.pdf", dpi=300, bbox_inches='tight')

plt.show()
# Out:
# --- Treinando Master Model com 1 Feature(s) [+ mfcc_6] ---
# 09:35:06 - [ModelEvaluator] - INFO - Executing Rigorous Stress Test (Model Evaluation)...
# 09:35:06 - [ModelEvaluator] - INFO - Test Results -> F1-Macro: 0.2096 | PR-AUC: 0.36513451839132366
# --- Treinando Master Model com 2 Feature(s) [+ wav_detail_lvl5_std] ---
# 09:35:31 - [ModelEvaluator] - INFO - Executing Rigorous Stress Test (Model Evaluation)...
# 09:35:31 - [ModelEvaluator] - INFO - Test Results -> F1-Macro: 0.3033 | PR-AUC: 0.4067298538375642
# --- Treinando Master Model com 3 Feature(s) [+ mfcc_3] ---
# 09:35:51 - [ModelEvaluator] - INFO - Executing Rigorous Stress Test (Model Evaluation)...
# 09:35:52 - [ModelEvaluator] - INFO - Test Results -> F1-Macro: 0.2883 | PR-AUC: 0.4013855450503976
# --- Treinando Master Model com 4 Feature(s) [+ wav_detail_lvl3_std] ---
# 09:37:25 - [ModelEvaluator] - INFO - Executing Rigorous Stress Test (Model Evaluation)...
# 09:37:25 - [ModelEvaluator] - INFO - Test Results -> F1-Macro: 0.3071 | PR-AUC: 0.41406990060548327
# --- Treinando Master Model com 5 Feature(s) [+ wav_detail_lvl4_std] ---
# 09:42:16 - [ModelEvaluator] - INFO - Executing Rigorous Stress Test (Model Evaluation)...
# 09:42:16 - [ModelEvaluator] - INFO - Test Results -> F1-Macro: 0.3143 | PR-AUC: 0.4316426252875864
# --- Treinando Master Model com 6 Feature(s) [+ rms_mean] ---
# 09:48:02 - [ModelEvaluator] - INFO - Executing Rigorous Stress Test (Model Evaluation)...
# 09:48:03 - [ModelEvaluator] - INFO - Test Results -> F1-Macro: 0.3258 | PR-AUC: 0.43066054981694535
# --- Treinando Master Model com 7 Feature(s) [+ mfcc_1] ---
# 09:53:06 - [ModelEvaluator] - INFO - Executing Rigorous Stress Test (Model Evaluation)...
# 09:53:07 - [ModelEvaluator] - INFO - Test Results -> F1-Macro: 0.2769 | PR-AUC: 0.3787013735915078
# --- Treinando Master Model com 8 Feature(s) [+ mae] ---
# 09:58:35 - [ModelEvaluator] - INFO - Executing Rigorous Stress Test (Model Evaluation)...
# 09:58:35 - [ModelEvaluator] - INFO - Test Results -> F1-Macro: 0.3018 | PR-AUC: 0.38243728608191596
# --- Treinando Master Model com 9 Feature(s) [+ mfcc_std] ---
# 10:04:21 - [ModelEvaluator] - INFO - Executing Rigorous Stress Test (Model Evaluation)...
# 10:04:21 - [ModelEvaluator] - INFO - Test Results -> F1-Macro: 0.3245 | PR-AUC: 0.41113017659854006
# --- Treinando Master Model com 10 Feature(s) [+ mfcc_5] ---
# 10:09:16 - [ModelEvaluator] - INFO - Executing Rigorous Stress Test (Model Evaluation)...
# 10:09:16 - [ModelEvaluator] - INFO - Test Results -> F1-Macro: 0.3977 | PR-AUC: 0.4173030150789674
# --- Treinando Master Model com 11 Feature(s) [+ mfcc_11] ---
# 10:13:24 - [ModelEvaluator] - INFO - Executing Rigorous Stress Test (Model Evaluation)...
# 10:13:24 - [ModelEvaluator] - INFO - Test Results -> F1-Macro: 0.3849 | PR-AUC: 0.40748432467977463
# --- Treinando Master Model com 12 Feature(s) [+ mfcc_var] ---
# 10:17:54 - [ModelEvaluator] - INFO - Executing Rigorous Stress Test (Model Evaluation)...
# 10:17:55 - [ModelEvaluator] - INFO - Test Results -> F1-Macro: 0.4177 | PR-AUC: 0.4112744859019803
# --- Treinando Master Model com 13 Feature(s) [+ wav_approx_std] ---
# 10:22:15 - [ModelEvaluator] - INFO - Executing Rigorous Stress Test (Model Evaluation)...
# 10:22:16 - [ModelEvaluator] - INFO - Test Results -> F1-Macro: 0.4313 | PR-AUC: 0.425194110856202
# --- Treinando Master Model com 14 Feature(s) [+ rms_std] ---
# 10:27:17 - [ModelEvaluator] - INFO - Executing Rigorous Stress Test (Model Evaluation)...
# 10:27:18 - [ModelEvaluator] - INFO - Test Results -> F1-Macro: 0.4560 | PR-AUC: 0.4241842709313784
# --- Treinando Master Model com 15 Feature(s) [+ wav_detail_lvl2_std] ---
# 10:32:10 - [ModelEvaluator] - INFO - Executing Rigorous Stress Test (Model Evaluation)...
# 10:32:10 - [ModelEvaluator] - INFO - Test Results -> F1-Macro: 0.4293 | PR-AUC: 0.4189689404436595
# --- Treinando Master Model com 16 Feature(s) [+ wav_detail_lvl5_energy] ---
# 10:37:35 - [ModelEvaluator] - INFO - Executing Rigorous Stress Test (Model Evaluation)...
# 10:37:35 - [ModelEvaluator] - INFO - Test Results -> F1-Macro: 0.4406 | PR-AUC: 0.42917338010435524
# --- Treinando Master Model com 17 Feature(s) [+ psd_std] ---
# 10:41:58 - [ModelEvaluator] - INFO - Executing Rigorous Stress Test (Model Evaluation)...
# 10:41:59 - [ModelEvaluator] - INFO - Test Results -> F1-Macro: 0.4527 | PR-AUC: 0.4369820452371089
# --- Treinando Master Model com 18 Feature(s) [+ mfcc_8] ---
# 10:44:34 - [ModelEvaluator] - INFO - Executing Rigorous Stress Test (Model Evaluation)...
# 10:44:35 - [ModelEvaluator] - INFO - Test Results -> F1-Macro: 0.4452 | PR-AUC: 0.44500754620541505
# --- Treinando Master Model com 19 Feature(s) [+ wav_detail_lvl1_std] ---
# 10:47:07 - [ModelEvaluator] - INFO - Executing Rigorous Stress Test (Model Evaluation)...
# 10:47:07 - [ModelEvaluator] - INFO - Test Results -> F1-Macro: 0.4520 | PR-AUC: 0.4438346098642752
# --- Treinando Master Model com 20 Feature(s) [+ wav_detail_lvl1_std] ---
# 10:49:38 - [ModelEvaluator] - INFO - Executing Rigorous Stress Test (Model Evaluation)...
# 10:49:39 - [ModelEvaluator] - INFO - Test Results -> F1-Macro: 0.4520 | PR-AUC: 0.4438346098642752
#
# 📊 Tabela de Desempenho Incremental (Master Model):
#     Dimensao  Ultima_Feature_Inclusa  F1_Macro
# 0          1                  mfcc_6  0.209591
# 1          2     wav_detail_lvl5_std  0.303337
# 2          3                  mfcc_3  0.288346
# 3          4     wav_detail_lvl3_std  0.307132
# 4          5     wav_detail_lvl4_std  0.314264
# 5          6                rms_mean  0.325830
# 6          7                  mfcc_1  0.276889
# 7          8                     mae  0.301840
# 8          9                mfcc_std  0.324542
# 9         10                  mfcc_5  0.397660
# 10        11                 mfcc_11  0.384942
# 11        12                mfcc_var  0.417657
# 12        13          wav_approx_std  0.431257
# 13        14                 rms_std  0.455950
# 14        15     wav_detail_lvl2_std  0.429310
# 15        16  wav_detail_lvl5_energy  0.440570
# 16        17                 psd_std  0.452701
# 17        18                  mfcc_8  0.445150
# 18        19     wav_detail_lvl1_std  0.451969
# 19        20     wav_detail_lvl1_std  0.451969
